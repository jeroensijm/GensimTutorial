# %%
# https://www.machinelearningplus.com/nlp/gensim-tutorial/

# %% [markdown]
# ### 11. How to create Topic Models with LDA?

# %% [markdown]
# The objective of topic models is to extract the underlying topics from a given collection of text documents. Each document in the text is considered as a combination of topics and each topic is considered as a combination of related words.
#
# Topic modeling can be done by algorithms like Latent Dirichlet Allocation (LDA) and Latent Semantic Indexing (LSI).
#
# In both cases you need to provide the number of topics as input. The topic model, in turn, will provide the topic keywords for each topic and the percentage contribution of topics in each document.
#
# The quality of topics is highly dependent on the quality of text processing and the number of topics you provide to the algorithm. The earlier post on how to build best topic models explains the procedure in more detail. However, I recommend understanding the basic steps involved and the interpretation in the example below.
#
# Step 0: Load the necessary packages and import the stopwords.

# %%
# Step 0: Import packages and stopwords
from gensim.models import LdaModel, LdaMulticore
from gensim import corpora
import gensim.downloader as api
from gensim.utils import simple_preprocess, lemmatize
from nltk.corpus import stopwords
import re
import logging
from pprint import pprint
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s')
logging.root.setLevel(level=logging.INFO)
stop_words = stopwords.words('english')
stop_words = stop_words + ['com', 'edu', 'subject', 'lines', 'organization', 'would', 'article', 'could']

# %%
# Step 1: Import the dataset and get the text and real topic of each news article
dataset = api.load("text8")
data = [d for d in dataset]

# %% [markdown]
# Step 2: Prepare the downloaded data by removing stopwords and lemmatize it. For Lemmatization, gensim requires the pattern package. So, be sure to do pip install pattern in your terminal or prompt before running this. !! if you get a pip erro 'OSError: mysql_config not found" then in OSX do:  brew install mariadb
#
# I have setup lemmatization such that only Nouns (NN), Adjectives (JJ) and Pronouns (RB) are retained. Because I prefer only such words to go as topic keywords. This is a personal choice.

# %%
#StopIteration error!
# try spacy below
# Step 2: Prepare Data (Remove stopwords and lemmatize)
data_processed = []

# for i, doc in enumerate(data[:100]):
#     doc_out = []
#     for wd in doc:
#         if wd not in stop_words:  # remove stopwords
#             lemmatized_word = lemmatize(wd, allowed_tags=re.compile('(NN|JJ|RB)'))  # lemmatize
#             if lemmatized_word:
#                 doc_out = doc_out + [lemmatized_word[0].split(b'/')[0].decode('utf-8')]
#         else:
#             continue
#     data_processed.append(doc_out)

# Print a small sample    
# print(data_processed[0][:5]) 
#> ['anarchism', 'originated', 'term', 'abuse', 'first']

# %%
import spacy

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent))
#         print(sent, doc)
        texts_out.append([token.lemma_ if token.lemma_ not in ['-PRON-'] else '' for token in doc if
                               token.pos_ in allowed_postags])
    return texts_out


# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# Run in terminal: python3 -m spacy download en
nlp = spacy.load('en', disable=['parser', 'ner'])

# Do lemmatization keeping only Noun, Adj, Verb, Adverb
data_processed = lemmatization(data[:100], allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

# %% [markdown]
# The data_processed is now processed as a list of list of words. You can now use this to create the Dictionary and Corpus, which will then be used as inputs to the LDA model.

# %%
# Step 3: Create the Inputs of LDA model: Dictionary and Corpus
dct = corpora.Dictionary(data_processed)
corpus = [dct.doc2bow(line) for line in data_processed]
# Out:
# 2019-03-24 15:38:00,100 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2019-03-24 15:38:00,555 : INFO : built Dictionary(43849 unique tokens: ['abacus', 'ability', 'able', 'abnormal', 'abolish']...) from 100 documents (total 575401 corpus positions)

# %% [markdown]
# We have the Dictionary and Corpus created. Let’s build a LDA topic model with 7 topics, using LdaMulticore(). 7 topics is an arbitrary choice for now.

# %%
# dct.token2id
[[(dct[id], count) for id, count in line] for line in corpus]
# Out:
# [[('abacus', 1),
#   ('ability', 4),
#   ('able', 7),
#   ('abnormal', 1),
#   ('abolish', 1),
#   ('abolition', 1),
#   ('about', 1),
#   ('absence', 2),
#   ('absolute', 2),
#   ('abstention', 1),
#   ('absurdity', 1),
#   ('abundance', 1),
#   ('abuse', 2),
#   ('academic', 1),
#   ('accept', 4),
#   ('access', 2),
#   ('accidentally', 1),
#   ('accommodation', 1),
#   ('accord', 3),
#   ('accordance', 1),
#   ('account', 1),
#   ('accumulate', 1),
#   ('accurately', 1),
#   ('accusation', 1),
#   ('achieve', 1),
#   ('achievement', 2),
#   ('act', 7),
#   ('acting', 1),
#   ('action', 12),
#   ('active', 4),
#   ('activism', 1),
#   ('activist', 1),
#   ('activity', 7),
#   ('adam', 1),
#   ('address', 1),
#   ('adherent', 1),
#   ('adjective', 1),
#   ('adjust', 1),
#   ('adopt', 2),
#   ('adult', 4),
#   ('advance', 2),
#   ('advocate', 12),
#   ('affect', 3),
#   ('affection', 1),
#   ('affinity', 1),
#   ('african', 1),
#   ('afterwards', 1),
#   ('age', 7),
#   ('aggression', 2),
#   ('aggressive', 1),
#   ('agitate', 1),
#   ('agitation', 1),
#   ('agitator', 1),
#   ('agree', 1),
#   ('agricultural', 1),
#   ('aid', 5),
#   ('aide', 3),
#   ('aim', 2),
#   ('alexander', 2),
#   ('alfredo', 1),
#   ('alfredsson', 1),
#   ('alienate', 1),
#   ('alienation', 1),
#   ('all', 3),
#   ('alliance', 3),
#   ('allow', 5),
#   ('almost', 2),
#   ('alone', 2),
#   ('already', 1),
#   ('also', 32),
#   ('alston', 1),
#   ('alternate', 1),
#   ('alternative', 2),
#   ('altogether', 1),
#   ('always', 2),
#   ('ambiguous', 1),
#   ('american', 6),
#   ('amoralism', 1),
#   ('amount', 2),
#   ('anabaptist', 4),
#   ('anarcha', 9),
#   ('anarchism', 102),
#   ('anarchist', 145),
#   ('anarchiste', 1),
#   ('anarchistic', 3),
#   ('anarcho', 19),
#   ('anarchoblog', 1),
#   ('anarchy', 16),
#   ('ancestor', 1),
#   ('ancient', 1),
#   ('andrej', 1),
#   ('andrew', 1),
#   ('anger', 1),
#   ('anglophone', 2),
#   ('annihilate', 1),
#   ('annihilation', 1),
#   ('announce', 1),
#   ('anomie', 1),
#   ('answer', 2),
#   ('anthropologist', 1),
#   ('anti', 16),
#   ('antifa', 1),
#   ('anxiety', 3),
#   ('anxious', 1),
#   ('anybody', 1),
#   ('apart', 2),
#   ('apparent', 1),
#   ('appeal', 1),
#   ('appear', 5),
#   ('appleton', 1),
#   ('apply', 3),
#   ('approach', 1),
#   ('appropriate', 3),
#   ('april', 2),
#   ('arbitration', 1),
#   ('archive', 2),
#   ('archon', 1),
#   ('area', 1),
#   ('argentina', 1),
#   ('argue', 10),
#   ('arise', 1),
#   ('arm', 2),
#   ('armand', 1),
#   ('armed', 4),
#   ('armoured', 1),
#   ('army', 2),
#   ('arrive', 2),
#   ('article', 5),
#   ('artist', 1),
#   ('as', 11),
#   ('asd', 1),
#   ('ashanti', 1),
#   ('asperger', 6),
#   ('assassination', 2),
#   ('assert', 2),
#   ('assessment', 1),
#   ('assist', 1),
#   ('associate', 7),
#   ('association', 6),
#   ('at', 4),
#   ('attach', 1),
#   ('attachment', 3),
#   ('attempt', 4),
#   ('attention', 2),
#   ('attitude', 1),
#   ('attribute', 1),
#   ('auberon', 1),
#   ('auditory', 1),
#   ('august', 1),
#   ('austrian', 2),
#   ('author', 5),
#   ('authoritarian', 16),
#   ('authoritarianism', 2),
#   ('authority', 7),
#   ('autism', 55),
#   ('autistic', 44),
#   ('auto', 1),
#   ('autonomism', 1),
#   ('autonomist', 1),
#   ('autonomous', 4),
#   ('autreat', 1),
#   ('avant', 1),
#   ('avoid', 1),
#   ('avow', 1),
#   ('aware', 1),
#   ('awareness', 1),
#   ('away', 3),
#   ('ayn', 1),
#   ('babble', 2),
#   ('back', 2),
#   ('bad', 1),
#   ('bakunin', 13),
#   ('ballot', 1),
#   ('baltimore', 1),
#   ('band', 3),
#   ('bank', 2),
#   ('banking', 1),
#   ('barcelona', 2),
#   ('baron', 1),
#   ('base', 9),
#   ('bath', 1),
#   ('bayonet', 1),
#   ('be', 291),
#   ('become', 10),
#   ('begin', 2),
#   ('beginning', 1),
#   ('behavior', 13),
#   ('behavioral', 3),
#   ('being', 2),
#   ('belief', 6),
#   ('believe', 15),
#   ('belong', 1),
#   ('below', 2),
#   ('beneficial', 3),
#   ('benjamin', 5),
#   ('berkman', 2),
#   ('berlin', 1),
#   ('bertrand', 1),
#   ('best', 1),
#   ('better', 1),
#   ('bey', 2),
#   ('bible', 1),
#   ('big', 2),
#   ('biodiversity', 1),
#   ('bios', 1),
#   ('birth', 1),
#   ('birthday', 1),
#   ('bitter', 1),
#   ('black', 5),
#   ('blame', 1),
#   ('bleed', 1),
#   ('bleuler', 1),
#   ('blog', 1),
#   ('board', 1),
#   ('bob', 2),
#   ('body', 5),
#   ('bolshevik', 9),
#   ('bolshevism', 2),
#   ('bomb', 1),
#   ('bombing', 1),
#   ('bonanno', 1),
#   ('bonobo', 1),
#   ('book', 9),
#   ('border', 1),
#   ('boston', 1),
#   ('bourgeois', 2),
#   ('bourgeoisie', 1),
#   ('bourne', 1),
#   ('bourse', 1),
#   ('branch', 2),
#   ('bread', 1),
#   ('brief', 1),
#   ('bring', 3),
#   ('broad', 2),
#   ('bryan', 1),
#   ('buddhist', 1),
#   ('building', 1),
#   ('bullet', 1),
#   ('bureaucratic', 1),
#   ('business', 1),
#   ('call', 13),
#   ('calm', 2),
#   ('camp', 2),
#   ('can', 28),
#   ('canada', 1),
#   ('cannon', 1),
#   ('capable', 1),
#   ('capital', 1),
#   ('capitalism', 15),
#   ('capitalist', 8),
#   ('caplan', 1),
#   ('car', 2),
#   ('care', 1),
#   ('carelessness', 1),
#   ('carl', 1),
#   ('carry', 3),
#   ('case', 2),
#   ('catalonia', 1),
#   ('caucasian', 1),
#   ('cause', 4),
#   ('cease', 1),
#   ('celebrate', 1),
#   ('celebrity', 1),
#   ('central', 1),
#   ('century', 8),
#   ('cercle', 1),
#   ('certain', 8),
#   ('certainly', 1),
#   ('certainty', 1),
#   ('cgt', 5),
#   ('chance', 1),
#   ('change', 3),
#   ('chaos', 3),
#   ('character', 1),
#   ('characterise', 3),
#   ('characteristic', 3),
#   ('characterization', 1),
#   ('characterize', 1),
#   ('chat', 1),
#   ('cheek', 1),
#   ('chiapas', 1),
#   ('chief', 1),
#   ('child', 35),
#   ('childhood', 1),
#   ('chimpanzee', 1),
#   ('china', 1),
#   ('chinese', 3),
#   ('choice', 1),
#   ('chomsky', 4),
#   ('christian', 8),
#   ('christiania', 1),
#   ('christianity', 1),
#   ('church', 3),
#   ('cite', 2),
#   ('citium', 1),
#   ('city', 1),
#   ('civil', 9),
#   ('civilization', 4),
#   ('claim', 7),
#   ('class', 12),
#   ('classic', 1),
#   ('classical', 2),
#   ('classification', 1),
#   ('classify', 1),
#   ('classroom', 2),
#   ('cleaner', 1),
#   ('clear', 2),
#   ('clearinghouse', 1),
#   ('clearly', 1),
#   ('cleyre', 3),
#   ('climax', 1),
#   ('clinical', 1),
#   ('clinician', 3),
#   ('close', 1),
#   ('clumsiness', 1),
#   ('cnt', 14),
#   ('co', 3),
#   ('coalition', 1),
#   ('cocktail', 1),
#   ('coercion', 2),
#   ('coercive', 1),
#   ('coexist', 1),
#   ('cognitive', 1),
#   ('coherent', 1),
#   ('collective', 2),
#   ('collectively', 1),
#   ('collectivise', 1),
#   ('collectivism', 1),
#   ('collectivize', 1),
#   ('colonialism', 1),
#   ('color', 2),
#   ('combat', 1),
#   ('combination', 2),
#   ('come', 5),
#   ('comfort', 1),
#   ('comfortably', 1),
#   ('comment', 1),
#   ('common', 5),
#   ('commonly', 2),
#   ('communal', 1),
#   ('commune', 3),
#   ('communicate', 4),
#   ('communication', 7),
#   ('communism', 9),
#   ('communist', 15),
#   ('communistic', 1),
#   ('communitarian', 1),
#   ('community', 9),
#   ('companionship', 1),
#   ('company', 1),
#   ('compassion', 1),
#   ('compatibility', 1),
#   ('compete', 1),
#   ('competite', 1),
#   ('competition', 4),
#   ('complete', 5),
#   ('complex', 1),
#   ('component', 1),
#   ('comunismo', 1),
#   ('conceivable', 1),
#   ('concept', 5),
#   ('conception', 2),
#   ('concern', 3),
#   ('conclude', 2),
#   ('conclusion', 1),
#   ('condition', 7),
#   ('condone', 1),
#   ('conf', 1),
#   ('confederaci', 2),
#   ('confederation', 2),
#   ('confine', 1),
#   ('conflict', 7),
#   ('confront', 1),
#   ('confused', 1),
#   ('congress', 1),
#   ('conquest', 1),
#   ('conscience', 1),
#   ('conscious', 1),
#   ('consensus', 1),
#   ('consequence', 1),
#   ('consequently', 1),
#   ('conservative', 1),
#   ('consider', 9),
#   ('considerably', 1),
#   ('consistency', 1),
#   ('consistent', 3),
#   ('consolidate', 1),
#   ('construct', 1),
#   ('contact', 1),
#   ('contemporary', 4),
#   ('context', 2),
#   ('continue', 3),
#   ('contractarianism', 1),
#   ('contrary', 1),
#   ('contrast', 1),
#   ('contribute', 1),
#   ('control', 5),
#   ('controversial', 2),
#   ('controversially', 1),
#   ('conversation', 2),
#   ('converse', 2),
#   ('coo', 1),
#   ('cop', 1),
#   ('cope', 1),
#   ('copenhagen', 1),
#   ('corresponding', 1),
#   ('corrupt', 1),
#   ('cost', 1),
#   ('could', 2),
#   ('council', 1),
#   ('counterpart', 1),
#   ('country', 1),
#   ('coup', 2),
#   ('cover', 1),
#   ('crass', 1),
#   ('create', 5),
#   ('creation', 2),
#   ('crimethinc', 1),
#   ('criminality', 1),
#   ('crisis', 1),
#   ('criterion', 3),
#   ('critic', 3),
#   ('critical', 1),
#   ('criticise', 4),
#   ('criticism', 2),
#   ('criticize', 2),
#   ('criticse', 1),
#   ('critique', 4),
#   ('crowd', 1),
#   ('crucially', 1),
#   ('crush', 1),
#   ('cry', 1),
#   ('crypto', 1),
#   ('cuddle', 2),
#   ('cue', 1),
#   ('culminate', 1),
#   ('culotte', 1),
#   ('cultural', 5),
#   ('culture', 4),
#   ('cure', 2),
#   ('current', 4),
#   ('cyber', 1),
#   ('cypherpunk', 1),
#   ('d', 2),
#   ('daily', 2),
#   ('damage', 1),
#   ('dan', 1),
#   ('dangerous', 1),
#   ('date', 1),
#   ('dave', 1),
#   ('david', 3),
#   ('day', 5),
#   ('deal', 1),
#   ('debate', 2),
#   ('decade', 1),
#   ('december', 1),
#   ('decentralisation', 1),
#   ('decentralize', 1),
#   ('decide', 1),
#   ('decipher', 1),
#   ('declare', 1),
#   ('decreed', 2),
#   ('dedicate', 2),
#   ('deed', 2),
#   ('deep', 1),
#   ('defeat', 1),
#   ('defend', 3),
#   ('define', 4),
#   ('definition', 2),
#   ('defunct', 1),
#   ('degree', 4),
#   ('del', 2),
#   ('delay', 7),
#   ('deleuze', 1),
#   ('demand', 1),
#   ('democracy', 1),
#   ('democrat', 2),
#   ('democratic', 1),
#   ('denmark', 1),
#   ('denounce', 1),
#   ('depressed', 1),
#   ('derive', 1),
#   ('describe', 9),
#   ('description', 1),
#   ('desirable', 2),
#   ('desire', 2),
#   ('destroy', 3),
#   ('destruction', 2),
#   ('detail', 1),
#   ('detailed', 1),
#   ('determine', 2),
#   ('develop', 11),
#   ('development', 8),
#   ('developmental', 3),
#   ('device', 1),
#   ('diagnose', 4),
#   ('diagnosis', 4),
#   ('diagnostic', 4),
#   ('dielo', 1),
#   ('differ', 2),
#   ('difference', 3),
#   ('different', 12),
#   ('differently', 1),
#   ('difficult', 4),
#   ('difficulty', 8),
#   ('digger', 2),
#   ('dilettante', 1),
#   ('direct', 3),
#   ('direction', 1),
#   ('directive', 1),
#   ('directly', 1),
#   ('disagreement', 2),
#   ('disappear', 1),
#   ('discussion', 2),
#   ('dislike', 1),
#   ('dismiss', 1),
#   ('disobedience', 1),
#   ('disorder', 13),
#   ('display', 2),
#   ('dispute', 1),
#   ('dissident', 1),
#   ('distance', 1),
#   ('distasteful', 1),
#   ('distinct', 2),
#   ('distract', 1),
#   ('distribute', 1),
#   ('disturb', 1),
#   ('diverse', 2),
#   ('diversity', 2),
#   ('divide', 2),
#   ('division', 2),
#   ('do', 24),
#   ('doctrine', 2),
#   ('dogmatic', 1),
#   ('domestically', 1),
#   ('dominance', 1),
#   ('domination', 3),
#   ('don', 2),
#   ('downtown', 1),
#   ('dr', 1),
#   ('dress', 1),
#   ('drive', 1),
#   ('dsm', 4),
#   ('du', 1),
#   ('due', 2),
#   ('dutch', 1),
#   ('dynamic', 1),
#   ('dynamite', 1),
#   ('dynamost', 1),
#   ('dysfunction', 1),
#   ('e', 3),
#   ('early', 17),
#   ('earn', 1),
#   ('earth', 4),
#   ('earthly', 2),
#   ('easily', 4),
#   ('eastern', 1),
#   ('easy', 1),
#   ('echolalia', 1),
#   ('eclectic', 1),
#   ('eco', 3),
#   ('ecofeminism', 1),
#   ('ecology', 1),
#   ('economic', 10),
#   ('economical', 1),
#   ('economy', 2),
#   ('edit', 1),
#   ('edition', 1),
#   ('editor', 1),
#   ('education', 3),
#   ('educational', 2),
#   ('effect', 2),
#   ('effort', 1),
#   ('egalitarian', 1),
#   ('ego', 2),
#   ('egoism', 4),
#   ('egoist', 3),
#   ('either', 1),
#   ('elaborate', 1),
#   ('elect', 1),
#   ('election', 3),
#   ('electoral', 1),
#   ('element', 1),
#   ('eliminate', 1),
#   ('elimination', 1),
#   ('elite', 1),
#   ('else', 1),
#   ('embody', 1),
#   ('embrace', 2),
#   ('emile', 2),
#   ('emma', 5),
#   ('emotion', 1),
#   ('emotional', 3),
#   ('emphasize', 1),
#   ('employment', 1),
#   ('emulate', 1),
#   ('encounter', 1),
#   ('encourage', 1),
#   ('encyclopedia', 1),
#   ('end', 3),
#   ('enemy', 2),
#   ('engage', 2),
#   ('engel', 2),
#   ('english', 6),
#   ('enjoyment', 1),
#   ('enough', 1),
#   ('enquiry', 1),
#   ('ensure', 2),
#   ('enter', 2),
#   ('entertainer', 1),
#   ('entirely', 1),
#   ('entry', 1),
#   ('environment', 7),
#   ('environmental', 2),
#   ('equal', 2),
#   ('equality', 2),
#   ('era', 1),
#   ('errico', 1),
#   ('ervin', 1),
#   ('escape', 1),
#   ('especially', 1),
#   ('espouse', 2),
#   ('essay', 1),
#   ('establish', 2),
#   ('establishment', 1),
#   ('estimate', 2),
#   ('ethic', 2),
#   ('ethnic', 2),
#   ('ethos', 1),
#   ('etiology', 1),
#   ('eugene', 1),
#   ('eurocentric', 1),
#   ('europe', 6),
#   ('european', 4),
#   ('evaluation', 1),
#   ('even', 10),
#   ('event', 4),
#   ('eventual', 2),
#   ('ever', 2),
#   ('everyday', 2),
#   ('everyone', 1),
#   ('evil', 1),
#   ('evolution', 1),
#   ('ex', 1),
#   ('example', 13),
#   ('excessive', 1),
#   ('exchange', 1),
#   ('exclusive', 1),
#   ('exemplifie', 1),
#   ('exhibit', 5),
#   ('exile', 2),
#   ('exist', 7),
#   ('existence', 1),
#   ('expansion', 1),
#   ('expect', 2),
#   ('expel', 1),
#   ('expense', 1),
#   ('experience', 2),
#   ('experimenal', 1),
#   ('experiment', 1),
#   ('experimental', 1),
#   ('explain', 4),
#   ('explicit', 2),
#   ('explicitly', 1),
#   ('exploit', 2),
#   ('explosive', 1),
#   ('exponent', 2),
#   ('expose', 1),
#   ('expound', 1),
#   ('express', 2),
#   ('expression', 7),
#   ('extend', 2),
#   ('extensive', 2),
#   ('extensively', 3),
#   ('external', 2),
#   ('extra', 1),
#   ('extreme', 1),
#   ('extremely', 1),
#   ('eye', 3),
#   ('fabbri', 1),
#   ('facade', 1),
#   ('face', 2),
#   ('facial', 4),
#   ('facilitate', 1),
#   ('fact', 2),
#   ('faction', 2),
#   ('factor', 2),
#   ('factory', 3),
#   ('fail', 2),
#   ('failure', 2),
#   ('fair', 1),
#   ('fairly', 1),
#   ('fall', 1),
#   ('familiar', 2),
#   ('family', 1),
#   ('famous', 5),
#   ('far', 1),
#   ('fascism', 6),
#   ('fascist', 12),
#   ('favor', 2),
#   ('favorite', 1),
#   ('favour', 1),
#   ('feature', 1),
#   ('february', 2),
#   ('federalism', 1),
#   ('federation', 5),
#   ('feel', 4),
#   ('feeling', 3),
#   ('female', 2),
#   ('feminism', 10),
#   ('feminist', 16),
#   ('few', 4),
#   ('fiction', 1),
#   ('field', 3),
#   ('fight', 6),
#   ('figure', 3),
#   ('figurehead', 1),
#   ('file', 2),
#   ('filter', 1),
#   ('final', 1),
#   ('find', 6),
#   ('fine', 1),
#   ('finger', 1),
#   ('first', 25),
#   ('flag', 1),
#   ('flap', 1),
#   ('flat', 1),
#   ('flore', 1),
#   ('fluctuation', 1),
#   ('focus', 5),
#   ('folk', 1),
#   ('follow', 6),
#   ('follower', 3),
#   ('following', 1),
#   ('food', 1),
#   ('force', 6),
#   ('foreign', 1),
#   ('forerunner', 2),
#   ('form', 21),
#   ('formal', 1),
#   ('formation', 1),
#   ('formet', 1),
#   ('formulate', 1),
#   ('formulation', 1),
#   ('forum', 2),
#   ('forward', 1),
#   ('found', 2),
#   ('founder', 2),
#   ('fourth', 1),
#   ('france', 5),
#   ('franco', 1),
#   ('fre', 1),
#   ('frederick', 1),
#   ('free', 7),
#   ('freedom', 2),
#   ('freely', 1),
#   ('freetown', 1),
#   ('freeze', 1),
#   ('french', 7),
#   ('friedman', 1),
#   ('friend', 3),
#   ('front', 5),
#   ('frustration', 1),
#   ('full', 1),
#   ('fully', 3),
#   ('fund', 1),
#   ('fundamental', 1),
#   ('further', 4),
#   ('g', 4),
#   ('gain', 2),
#   ('garden', 1),
#   ('gatherer', 2),
#   ('gaze', 2),
#   ('gender', 1),
#   ('gene', 1),
#   ('general', 12),
#   ('generalization', 1),
#   ('generally', 2),
#   ('generate', 1),
#   ('genetically', 1),
#   ('genuine', 1),
#   ('george', 1),
#   ('germany', 3),
#   ('germinal', 1),
#   ('gesture', 3),
#   ('get', 2),
#   ('ghost', 1),
#   ('gift', 1),
#   ('gille', 1),
#   ('girondin', 1),
#   ('give', 9),
#   ('global', 1),
#   ('globalization', 4),
#   ('glorification', 1),
#   ('gnu', 1),
#   ('go', 5),
#   ('goal', 1),
#   ('god', 4),
#   ('godwin', 5),
#   ('goldman', 7),
#   ('good', 9),
#   ('gorilla', 1),
#   ('governance', 1),
#   ('government', 9),
#   ('grab', 1),
#   ('graeber', 1),
#   ('grasp', 1),
#   ('great', 3),
#   ('greek', 3),
#   ('green', 5),
#   ('greene', 2),
#   ('ground', 1),
#   ('group', 24),
#   ('grouping', 1),
#   ('grow', 2),
#   ('grubacic', 1),
#   ('guattari', 1),
#   ('guide', 1),
#   ('guin', 1),
#   ('gun', 1),
#   ('gustave', 1),
#   ('hague', 1),
#   ('hakim', 2),
#   ('han', 3),
#   ('hand', 2),
#   ('handle', 1),
#   ('happily', 1),
#   ('hard', 1),
#   ('harm', 1),
#   ('harmonious', 1),
#   ('harmony', 1),
#   ('harsh', 1),
#   ('hart', 1),
#   ('have', 74),
#   ('haymarket', 1),
#   ('head', 2),
#   ('health', 2),
#   ('hear', 4),
#   ('heavily', 1),
#   ('heinlein', 1),
#   ('help', 8),
#   ('herbert', 3),
#   ('here', 1),
#   ('heterodox', 1),
#   ('hide', 1),
#   ('hierarchical', 1),
#   ('hierarchy', 4),
#   ('high', 7),
#   ('highly', 4),
#   ('hip', 1),
#   ('historian', 2),
#   ('historical', 3),
#   ('history', 5),
#   ('hold', 7),
#   ('holder', 1),
#   ('holy', 1),
#   ('home', 1),
#   ('hop', 1),
#   ('hopkin', 1),
#   ('hospital', 1),
#   ('hour', 2),
#   ('housing', 1),
#   ('how', 5),
#   ('howard', 1),
#   ('however', 16),
#   ('hug', 1),
#   ('human', 5),
#   ('hundred', 1),
#   ('hunter', 2),
#   ('hurl', 1),
#   ('hutterite', 1),
#   ('hypocrisy', 2),
#   ('icd', 1),
#   ('idea', 22),
#   ('identify', 2),
#   ('ideological', 2),
#   ('ideology', 3),
#   ('ii', 1),
#   ('ill', 1),
#   ('illegitimate', 2),
#   ('illusion', 1),
#   ('illustrate', 1),
#   ('image', 1),
#   ('imaginable', 1),
#   ('imaginary', 2),
#   ('imaginative', 1),
#   ('impact', 2),
#   ('impairment', 2),
#   ('imperialism', 1),
#   ('imply', 1),
#   ('importance', 1),
#   ('important', 5),
#   ('impose', 2),
#   ('impossibility', 1),
#   ('impossible', 2),
#   ('imprison', 1),
#   ('improve', 1),
#   ('impulsive', 1),
#   ('in', 1),
#   ('inability', 3),
#   ('inappropriately', 1),
#   ('incidence', 1),
#   ('inclined', 1),
#   ('include', 24),
#   ('incompatible', 1),
#   ('incorporate', 1),
#   ('increase', 3),
#   ('incredible', 1),
#   ('indeed', 2),
#   ('indian', 1),
#   ('indicator', 3),
#   ('indifferent', 1),
#   ('indigenous', 1),
#   ('individual', 23),
#   ('individualist', 9),
#   ('individualistically', 1),
#   ('industrial', 9),
#   ('indymedia', 1),
#   ('inevitable', 1),
#   ('infant', 2),
#   ('infantile', 2),
#   ('inflection', 1),
#   ('influence', 5),
#   ('influential', 3),
#   ('informal', 1),
#   ('information', 5),
#   ('infoshop', 3),
#   ('inherent', 2),
#   ('inherently', 1),
#   ('initially', 3),
#   ('initiate', 1),
#   ('injury', 1),
#   ('input', 1),
#   ('insanity', 1),
#   ('insight', 1),
#   ('inspire', 4),
#   ('instead', 2),
#   ('institute', 2),
#   ('institution', 8),
#   ('instructor', 1),
#   ('insult', 1),
#   ('insurrection', 2),
#   ('insurrectionary', 4),
#   ('integrated', 1),
#   ('integration', 1),
#   ('intellectual', 1),
#   ('intense', 2),
#   ('intention', 2),
#   ('interact', 2),
#   ('interaction', 7),
#   ('interest', 9),
#   ('interested', 1),
#   ('interfere', 1),
#   ('internal', 1),
#   ('international', 10),
#   ('internationally', 1),
#   ('internet', 1),
#   ('interpret', 1),
#   ('interpretation', 6),
#   ('intervene', 1),
#   ('intervention', 1),
#   ('introduce', 2),
#   ('involve', 5),
#   ('ireland', 1),
#   ('isaac', 1),
#   ('issue', 4),
#   ('italian', 1),
#   ('italy', 1),
#   ('item', 1),
#   ('iv', 1),
#   ('iww', 2),
#   ('jacque', 1),
#   ('january', 1),
#   ('jason', 1),
#   ('jean', 1),
#   ('jenny', 1),
#   ('jesus', 1),
#   ('joe', 1),
#   ('johann', 2),
#   ('johns', 1),
#   ('join', 7),
#   ('joseph', 4),
#   ('josiah', 2),
#   ('journal', 4),
#   ('joy', 2),
#   ('joyous', 1),
#   ('juliette', 1),
#   ('just', 4),
#   ('justice', 2),
#   ('justify', 3),
#   ('kanner', 3),
#   ('karl', 1),
#   ('key', 3),
#   ('kill', 1),
#   ('kind', 3),
#   ('king', 2),
#   ('kingdom', 3),
#   ('know', 11),
#   ('knowledge', 1),
#   ('komboa', 1),
#   ...],
#  [('ability', 3),
#   ('able', 3),
#   ('abnormal', 3),
#   ('about', 13),
#   ('absolute', 1),
#   ('accept', 3),
#   ('access', 1),
#   ('accidentally', 1),
#   ('accord', 7),
#   ('account', 3),
#   ('accurately', 1),
#   ('achieve', 2),
#   ('act', 2),
#   ('action', 1),
#   ('activity', 3),
#   ('address', 1),
#   ('adopt', 2),
#   ('adult', 8),
#   ('advance', 1),
#   ('affect', 2),
#   ('african', 2),
#   ('age', 5),
#   ('agree', 2),
#   ('agricultural', 1),
#   ('aid', 1),
#   ('all', 2),
#   ('alliance', 1),
#   ('allow', 2),
#   ('almost', 1),
#   ('alone', 1),
#   ('already', 1),
#   ('also', 23),
#   ('alternative', 1),
#   ('always', 1),
#   ('american', 12),
#   ('amount', 5),
#   ('anarchist', 1),
#   ('ancient', 4),
#   ('andrew', 1),
#   ('anger', 2),
#   ('answer', 2),
#   ('anti', 4),
#   ('anybody', 2),
#   ('apparent', 1),
#   ('appear', 5),
#   ('apply', 2),
#   ('approach', 3),
#   ('appropriate', 1),
#   ('april', 1),
#   ('area', 26),
#   ('argue', 5),
#   ('arise', 1),
#   ('arm', 1),
#   ('army', 2),
#   ('article', 8),
#   ('as', 10),
#   ('asd', 1),
#   ('asperger', 15),
#   ('assert', 3),
#   ('associate', 1),
#   ('association', 2),
#   ('at', 6),
#   ('attach', 1),
#   ('attempt', 3),
#   ('attention', 2),
#   ('august', 3),
#   ('author', 2),
#   ('authority', 2),
#   ('autism', 105),
#   ('autistic', 61),
#   ('avoid', 1),
#   ('awareness', 4),
#   ('away', 2),
#   ('back', 8),
#   ('band', 2),
#   ('bank', 2),
#   ('base', 4),
#   ('be', 353),
#   ('become', 12),
#   ('begin', 10),
#   ('behavior', 3),
#   ('behavioral', 1),
#   ('belief', 1),
#   ('believe', 2),
#   ('better', 2),
#   ('bible', 1),
#   ('birth', 3),
#   ('birthday', 1),
#   ('black', 3),
#   ('blog', 1),
#   ('body', 6),
#   ('book', 1),
#   ('boston', 1),
#   ('branch', 1),
#   ('bring', 5),
#   ('broad', 1),
#   ('building', 3),
#   ('call', 3),
#   ('can', 20),
#   ('canada', 1),
#   ('capable', 1),
#   ('capital', 9),
#   ('car', 1),
#   ('carry', 1),
#   ('case', 6),
#   ('cause', 6),
#   ('central', 8),
#   ('century', 8),
#   ('certain', 4),
#   ('chance', 1),
#   ('change', 10),
#   ('character', 6),
#   ('characteristic', 1),
#   ('child', 12),
#   ('childhood', 7),
#   ('christian', 1),
#   ('church', 2),
#   ('cite', 1),
#   ('city', 16),
#   ('civil', 3),
#   ('claim', 3),
#   ('class', 2),
#   ('classic', 1),
#   ('classical', 2),
#   ('classification', 2),
#   ('classify', 1),
#   ('classroom', 1),
#   ('clear', 2),
#   ('clearinghouse', 2),
#   ('clinician', 1),
#   ('color', 3),
#   ('combination', 1),
#   ('come', 3),
#   ('common', 8),
#   ('commonly', 1),
#   ('communicate', 4),
#   ('communication', 8),
#   ('community', 7),
#   ('companionship', 1),
#   ('company', 1),
#   ('compatibility', 1),
#   ('complete', 1),
#   ('complex', 1),
#   ('component', 1),
#   ('conceivable', 1),
#   ('concept', 1),
#   ('conception', 2),
#   ('condition', 6),
#   ('confederation', 1),
#   ('consequence', 1),
#   ('conservative', 2),
#   ('consider', 3),
#   ('construct', 1),
#   ('contact', 2),
#   ('continue', 6),
#   ('contrary', 1),
#   ('contribute', 1),
#   ('control', 3),
#   ('controversial', 3),
#   ('conversation', 1),
#   ('converse', 1),
#   ('could', 2),
#   ('country', 4),
#   ('cover', 7),
#   ('create', 7),
#   ('criterion', 4),
#   ('culture', 11),
#   ('cure', 9),
#   ('current', 6),
#   ('d', 2),
#   ('daily', 3),
#   ('date', 3),
#   ('day', 3),
#   ('decade', 1),
#   ('december', 2),
#   ('decide', 2),
#   ('declare', 1),
#   ('deep', 1),
#   ('degree', 1),
#   ('delay', 5),
#   ('demand', 1),
#   ('democrat', 2),
#   ('democratic', 6),
#   ('derive', 2),
#   ('describe', 4),
#   ('desire', 1),
#   ('destruction', 1),
#   ('detail', 1),
#   ('determine', 2),
#   ('develop', 5),
#   ('development', 7),
#   ('developmental', 15),
#   ('diagnose', 2),
#   ('diagnosis', 14),
#   ('diagnostic', 5),
#   ('difference', 4),
#   ('different', 6),
#   ('difficult', 2),
#   ('difficulty', 2),
#   ('direct', 2),
#   ('direction', 1),
#   ('directly', 1),
#   ('discussion', 1),
#   ('disorder', 39),
#   ('divide', 1),
#   ('division', 1),
#   ('do', 10),
#   ('don', 1),
#   ('dr', 1),
#   ('drive', 1),
#   ('dsm', 4),
#   ('due', 4),
#   ('dysfunction', 2),
#   ('e', 5),
#   ('early', 9),
#   ('earth', 4),
#   ('eastern', 2),
#   ('easy', 1),
#   ('economic', 1),
#   ('economy', 2),
#   ('education', 2),
#   ('educational', 1),
#   ('effect', 17),
#   ('election', 3),
#   ('electoral', 2),
#   ('element', 1),
#   ('else', 1),
#   ('emphasize', 2),
#   ('employment', 2),
#   ('encourage', 1),
#   ('encyclopedia', 1),
#   ('end', 5),
#   ('enemy', 1),
#   ('english', 7),
#   ('enough', 1),
#   ('ensure', 1),
#   ('enter', 2),
#   ('entirely', 2),
#   ('environment', 3),
#   ('environmental', 3),
#   ('equal', 1),
#   ('especially', 1),
#   ('establish', 1),
#   ('establishment', 3),
#   ('estimate', 3),
#   ('european', 3),
#   ('even', 8),
#   ('event', 1),
#   ('example', 10),
#   ('expect', 1),
#   ('experience', 4),
#   ('explain', 1),
#   ('express', 1),
#   ('extend', 1),
#   ('external', 2),
#   ('extreme', 1),
#   ('face', 1),
#   ('fact', 3),
#   ('factor', 3),
#   ('fail', 1),
#   ('fall', 4),
#   ('family', 5),
#   ('famous', 3),
#   ('far', 2),
#   ('february', 2),
#   ('federation', 1),
#   ('female', 2),
#   ('few', 2),
#   ('fiction', 1),
#   ('field', 2),
#   ('fight', 4),
#   ('final', 1),
#   ('find', 7),
#   ('fine', 1),
#   ('finger', 1),
#   ('first', 15),
#   ('flap', 1),
#   ('focus', 4),
#   ('follow', 9),
#   ('force', 3),
#   ('form', 17),
#   ('formation', 1),
#   ('forum', 2),
#   ('found', 2),
#   ('freedom', 1),
#   ('french', 2),
#   ('friend', 3),
#   ('front', 3),
#   ('further', 5),
#   ('g', 5),
#   ('gain', 1),
#   ('gene', 1),
#   ('general', 8),
#   ('generally', 10),
#   ('george', 3),
#   ('gesture', 1),
#   ('get', 3),
#   ('give', 9),
#   ('global', 5),
#   ('go', 4),
#   ('goal', 2),
#   ('god', 3),
#   ('government', 4),
#   ('great', 11),
#   ('greek', 16),
#   ('ground', 1),
#   ('group', 10),
#   ('grow', 1),
#   ('guide', 2),
#   ('hand', 4),
#   ('handle', 1),
#   ('have', 65),
#   ('head', 2),
#   ('health', 7),
#   ('help', 5),
#   ('high', 20),
#   ('history', 11),
#   ('hold', 3),
#   ('home', 3),
#   ('hour', 1),
#   ('how', 2),
#   ('however', 6),
#   ('human', 7),
#   ('idea', 1),
#   ('image', 2),
#   ('imaginative', 2),
#   ('impact', 2),
#   ('impairment', 3),
#   ('imply', 1),
#   ('importance', 1),
#   ('important', 4),
#   ('incidence', 3),
#   ('include', 11),
#   ('increase', 18),
#   ('indian', 1),
#   ('individual', 5),
#   ('industrial', 1),
#   ('infantile', 2),
#   ('influence', 2),
#   ('influential', 1),
#   ('information', 8),
#   ('initiate', 2),
#   ('instead', 1),
#   ('institute', 8),
#   ('integration', 2),
#   ('intellectual', 5),
#   ('interaction', 5),
#   ('interest', 6),
#   ('international', 4),
#   ('internet', 1),
#   ('interpret', 1),
#   ('intervention', 1),
#   ('introduce', 1),
#   ('involve', 1),
#   ('issue', 8),
#   ('italian', 1),
#   ('italy', 1),
#   ('item', 1),
#   ('january', 5),
#   ('join', 1),
#   ('just', 5),
#   ('kanner', 3),
#   ('kill', 1),
#   ('king', 2),
#   ('kingdom', 2),
#   ('know', 4),
#   ('knowledge', 1),
#   ('l', 2),
#   ('label', 7),
#   ('lack', 4),
#   ('land', 4),
#   ('language', 11),
#   ('large', 12),
#   ('last', 3),
#   ('late', 2),
#   ('later', 5),
#   ('latin', 6),
#   ('law', 4),
#   ('lead', 4),
#   ('leadership', 1),
#   ('learn', 2),
#   ('least', 6),
#   ('leave', 3),
#   ('left', 1),
#   ('less', 4),
#   ('level', 6),
#   ('liberalism', 1),
#   ('life', 4),
#   ('line', 4),
#   ('link', 3),
#   ('list', 5),
#   ('little', 7),
#   ('live', 7),
#   ('long', 3),
#   ('lose', 1),
#   ('lot', 1),
#   ('louis', 1),
#   ('low', 11),
#   ('lower', 2),
#   ('m', 6),
#   ('magazine', 1),
#   ('magnitude', 1),
#   ('main', 6),
#   ('mainly', 2),
#   ('mainstream', 1),
#   ('major', 6),
#   ('majority', 3),
#   ('make', 12),
#   ('male', 1),
#   ('man', 6),
#   ('manifest', 2),
#   ('manifestation', 1),
#   ('manual', 2),
#   ('many', 24),
#   ('match', 1),
#   ('material', 3),
#   ('may', 11),
#   ('mean', 7),
#   ('meaning', 2),
#   ('medium', 1),
#   ('meet', 1),
#   ('member', 2),
#   ('mental', 8),
#   ('method', 1),
#   ('mexico', 2),
#   ('mid', 1),
#   ('middle', 1),
#   ('mind', 1),
#   ('mode', 2),
#   ('model', 2),
#   ('modern', 6),
#   ('month', 7),
#   ('more', 20),
#   ('most', 16),
#   ('motor', 1),
#   ('movement', 5),
#   ('much', 6),
#   ('multiple', 2),
#   ('music', 2),
#   ('musical', 1),
#   ('must', 5),
#   ('name', 13),
#   ('national', 10),
#   ('natural', 3),
#   ('nature', 1),
#   ('nearly', 2),
#   ('necessarily', 1),
#   ('need', 4),
#   ('nervous', 2),
#   ('network', 1),
#   ('neurological', 2),
#   ('nevertheless', 1),
#   ('new', 9),
#   ('next', 1),
#   ('non', 1),
#   ('normal', 7),
#   ('north', 3),
#   ('not', 36),
#   ('notably', 1),
#   ('note', 3),
#   ('now', 4),
#   ('number', 8),
#   ('object', 2),
#   ('occasionally', 1),
#   ('occupation', 1),
#   ('occur', 3),
#   ('october', 4),
#   ('offer', 2),
#   ('official', 2),
#   ('often', 12),
#   ('old', 1),
#   ('once', 2),
#   ('one', 7),
#   ('online', 3),
#   ('only', 8),
#   ('onset', 2),
#   ('open', 9),
#   ('opposition', 1),
#   ('order', 2),
#   ('org', 5),
#   ('organisation', 2),
#   ('organization', 2),
#   ('origin', 2),
#   ('other', 23),
#   ('own', 3),
#   ('paper', 2),
#   ('parent', 4),
#   ('paris', 1),
#   ('part', 16),
#   ('particular', 5),
#   ('particularly', 2),
#   ('party', 9),
#   ('past', 3),
#   ('patient', 2),
#   ('pattern', 5),
#   ('pdd', 4),
#   ('pearl', 3),
#   ('pediatric', 2),
#   ('people', 18),
#   ('perhaps', 1),
#   ('period', 3),
#   ('persistent', 1),
#   ('person', 10),
#   ('personal', 1),
#   ('perspective', 1),
#   ('pervasive', 12),
#   ('phenomenon', 1),
#   ('phrase', 3),
#   ('physical', 1),
#   ('physically', 1),
#   ('pitch', 1),
#   ('place', 1),
#   ('plain', 2),
#   ('play', 7),
#   ('point', 5),
#   ('policy', 1),
#   ('politic', 3),
#   ('political', 2),
#   ('poor', 1),
#   ('popular', 6),
#   ('population', 3),
#   ('possible', 1),
#   ('possibly', 1),
#   ('post', 1),
#   ('practice', 1),
#   ('predict', 1),
#   ('prediction', 1),
#   ('prefer', 1),
#   ('preoccupation', 2),
#   ('present', 5),
#   ('preserve', 1),
#   ('priest', 1),
#   ('primary', 1),
#   ('prior', 3),
#   ('problem', 3),
#   ('product', 5),
#   ('production', 3),
#   ('professional', 3),
#   ('professor', 2),
#   ('programming', 1),
#   ('property', 1),
#   ('proportion', 1),
#   ('proto', 1),
#   ('provide', 3),
#   ('psychiatric', 1),
#   ('publication', 1),
#   ('pursue', 1),
#   ('pursuit', 1),
#   ('qualitative', 1),
#   ('quite', 1),
#   ('race', 1),
#   ('racial', 1),
#   ('range', 5),
#   ('rather', 4),
#   ('re', 1),
#   ('read', 1),
#   ('reality', 1),
#   ('reason', 6),
#   ('receive', 2),
#   ('recent', 3),
#   ('recently', 2),
#   ('recognition', 1),
#   ('recognize', 2),
#   ('record', 1),
#   ('reduce', 1),
#   ('refer', 7),
#   ('reference', 7),
#   ('reflect', 5),
#   ('refuse', 5),
#   ('regard', 1),
#   ('region', 7),
#   ('reject', 1),
#   ('relate', 7),
#   ('related', 1),
#   ('relation', 1),
#   ('relatively', 4),
#   ('religion', 3),
#   ('religious', 1),
#   ('rely', 1),
#   ('remain', 3),
#   ('repetitive', 3),
#   ('report', 4),
#   ('reported', 1),
#   ('represent', 5),
#   ('republican', 5),
#   ('research', 6),
#   ('researcher', 1),
#   ('resist', 1),
#   ('resource', 10),
#   ('respond', 1),
#   ('responsibility', 1),
#   ('rest', 1),
#   ('restrict', 2),
#   ('result', 6),
#   ('return', 1),
#   ('right', 7),
#   ('rise', 7),
#   ('rival', 1),
#   ('rock', 2),
#   ('role', 1),
#   ('routine', 1),
#   ('rule', 3),
#   ('ruler', 5),
#   ('s', 24),
#   ('same', 4),
#   ('san', 1),
#   ('say', 4),
#   ('scale', 3),
#   ('school', 2),
#   ('science', 1),
#   ('scientist', 3),
#   ('second', 2),
#   ('section', 1),
#   ('see', 23),
#   ('seek', 4),
#   ('seem', 1),
#   ('self', 1),
#   ('sense', 1),
#   ('sensory', 2),
#   ('separate', 2),
#   ('series', 2),
#   ('set', 6),
#   ('several', 3),
#   ('short', 1),
#   ('should', 1),
#   ('show', 4),
#   ('sight', 1),
#   ('sign', 3),
#   ('significant', 4),
#   ('similar', 4),
#   ('simply', 2),
#   ('sing', 1),
#   ('single', 2),
#   ('situation', 1),
#   ('skill', 2),
#   ('slight', 1),
#   ('small', 4),
#   ('so', 4),
#   ('social', 11),
#   ('society', 3),
#   ('solely', 1),
#   ('someone', 1),
#   ('something', 1),
#   ('sometimes', 9),
#   ('soon', 1),
#   ('source', 3),
#   ('spanish', 2),
#   ('speak', 5),
#   ('specific', 4),
#   ('specifically', 1),
#   ('spectrum', 20),
#   ('speech', 4),
#   ('spirit', 1),
#   ('spontaneous', 1),
#   ('stage', 1),
#   ('start', 2),
#   ('state', 37),
#   ('statistical', 2),
#   ('stereotyped', 2),
#   ('still', 3),
#   ('stop', 3),
#   ('story', 2),
#   ('strategy', 1),
#   ('strong', 3),
#   ('strongly', 1),
#   ('structure', 2),
#   ('student', 2),
#   ('subject', 3),
#   ('successful', 2),
#   ('such', 10),
#   ('suddenly', 1),
#   ('suggest', 1),
#   ('support', 5),
#   ('suppression', 1),
#   ('sustain', 2),
#   ('symbol', 8),
#   ('symbolic', 3),
#   ('symptom', 6),
#   ('syndrome', 21),
#   ('system', 9),
#   ('t', 1),
#   ('take', 6),
#   ('talk', 2),
#   ('teach', 1),
#   ('technology', 1),
#   ('tend', 7),
#   ('term', 5),
#   ('test', 2),
#   ('text', 1),
#   ('theme', 2),
#   ('then', 2),
#   ('theory', 3),
#   ('there', 18),
#   ('therefore', 2),
#   ('think', 3),
#   ('thus', 2),
#   ('time', 12),
#   ('today', 3),
#   ('together', 1),
#   ('too', 1),
#   ('topic', 1),
#   ('total', 3),
#   ('trade', 1),
#   ('traditional', 1),
#   ('train', 1),
#   ('transform', 1),
#   ('translate', 1),
#   ('treatment', 4),
#   ('tree', 9),
#   ('trigger', 1),
#   ('true', 4),
#   ('truly', 1),
#   ('try', 1),
#   ('turn', 1),
#   ('twentieth', 2),
#   ('typical', 1),
#   ('typically', 2),
#   ('uk', 2),
#   ('union', 2),
#   ('united', 18),
#   ('universal', 4),
#   ('unknown', 1),
#   ('unusual', 1),
#   ('use', 26),
#   ('useful', 1),
#   ('usually', 7),
#   ('vacuum', 1),
#   ('value', 6),
#   ('variant', 3),
#   ('variety', 1),
#   ('various', 2),
#   ('vary', 2),
#   ('very', 7),
#   ('view', 6),
#   ('vision', 1),
#   ('vote', 6),
#   ('war', 10),
#   ('way', 4),
#   ('wealth', 3),
#   ('website', 3),
#   ('well', 8),
#   ('western', 1),
#   ('when', 17),
#   ('where', 4),
#   ('white', 3),
#   ('wide', 2),
#   ('widely', 1),
#   ('will', 4),
#   ('william', 1),
#   ('woman', 1),
#   ('word', 4),
#   ('work', 6),
#   ('worker', 1),
#   ('workshop', 1),
#   ('world', 3),
#   ('worldwide', 1),
#   ('would', 16),
#   ('write', 3),
#   ('writing', 1),
#   ('year', 11),
#   ('', 2),
#   ('aba', 2),
#   ('abandon', 1),
#   ('abbreviate', 1),
#   ('abbreviation', 2),
#   ('absorb', 2),
#   ('abstract', 2),
#   ('abu', 16),
#   ('abudhabi', 1),
#   ('aby', 1),
#   ('academy', 1),
#   ('acceptable', 1),
#   ('accompany', 1),
#   ('accomplish', 1),
#   ('accuracy', 1),
#   ('ace', 2),
#   ('achaean', 1),
#   ('achille', 35),
#   ('achillesin', 1),
#   ('achilleus', 1),
#   ('achle', 1),
#   ('acquire', 1),
#   ('actually', 3),
#   ('add', 1),
#   ('addition', 3),
#   ('adelle', 1),
#   ('adenosine', 1),
#   ('adequate', 1),
#   ('adherence', 1),
#   ('adia', 1),
#   ('adjectival', 1),
#   ('administer', 2),
#   ('administration', 1),
#   ('adultress', 1),
#   ('adventure', 1),
#   ('advocacy', 1),
#   ('ae', 1),
#   ('aeide', 1),
#   ('aerosol', 3),
#   ('aerospace', 1),
#   ('affirmative', 2),
#   ('affirmo', 1),
#   ('agamemnon', 4),
#   ('agency', 5),
#   ('agilent', 1),
#   ('agrarian', 1),
#   ('ain', 4),
#   ('aio', 1),
#   ('air', 1),
#   ('airline', 1),
#   ('airliner', 1),
#   ('airport', 2),
#   ('ajax', 1),
#   ('akhaioi', 1),
#   ('akhil', 1),
#   ('akhilleus', 2),
#   ('akhos', 1),
#   ('alabama', 47),
#   ('alabamian', 1),
#   ('alan', 1),
#   ('alanine', 1),
#   ('alaska', 2),
#   ('albedo', 31),
#   ('albedos', 2),
#   ('album', 2),
#   ('aleph', 1),
#   ('alge', 1),
#   ('algebraic', 1),
#   ('alibamu', 1),
#   ('alif', 1),
#   ('alpha', 3),
#   ('alphabet', 10),
#   ('alphabetic', 1),
#   ('altar', 1),
#   ('alternatively', 1),
#   ('ambrosia', 1),
#   ('america', 2),
#   ('aminoglycoside', 1),
#   ('amp', 1),
#   ('ampere', 1),
#   ('analysis', 1),
#   ('analyze', 1),
#   ('ancestry', 2),
#   ('anchor', 1),
#   ('angle', 3),
#   ('announcement', 1),
#   ('annually', 1),
#   ('anode', 1),
#   ('anoint', 1),
#   ('ansar', 1),
#   ('antarctica', 1),
#   ('antibiotic', 1),
#   ('antonio', 1),
#   ('anyone', 1),
#   ('aperture', 2),
#   ('apollo', 4),
#   ('appalachian', 1),
#   ('apparel', 1),
#   ('apparently', 2),
#   ('application', 1),
#   ('apprentice', 1),
#   ('arab', 8),
#   ('arabia', 3),
#   ('arabic', 2),
#   ('arc', 2),
#   ('archaeological', 1),
#   ('armor', 3),
#   ('around', 2),
#   ('arrangement', 1),
#   ('arsenal', 1),
#   ('artificial', 1),
#   ('ascii', 1),
#   ('asia', 1),
#   ('aside', 1),
#   ('ask', 1),
#   ('aspect', 1),
#   ('aspie', 2),
#   ('assistance', 1),
#   ('assume', 1),
#   ('asteroid', 2),
#   ('astronomy', 3),
#   ('astrophysic', 1),
#   ('athena', 1),
#   ('athletic', 2),
#   ('atmosphere', 1),
#   ('attack', 1),
#   ('atto', 1),
#   ('attract', 1),
#   ('attraction', 1),
#   ('attributable', 1),
#   ('attributive', 1),
#   ('aulis', 1),
#   ('austria', 1),
#   ('autismtoday', 1),
#   ('autismwebsite', 1),
#   ('automedon', 1),
#   ('available', 2),
#   ('average', 12),
#   ('axis', 1),
#   ('backing', 1),
#   ('badly', 1),
#   ('bahrain', 4),
#   ('balloon', 1),
#   ('bandage', 1),
#   ('bani', 1),
#   ('baptist', 1),
#   ('barasti', 1),
#   ('barren', 1),
#   ('barry', 1),
#   ('baseball', 1),
#   ('basis', 2),
#   ('battery', 1),
#   ('battista', 1),
#   ('battle', 3),
#   ('bay', 1),
#   ('bc', 4),
#   ('beach', 1),
#   ('bear', 2),
#   ('beauty', 1),
#   ('beggar', 1),
#   ('behaviour', 2),
#   ('beloved', 1),
#   ('belt', 2),
#   ('benouvillein', 1),
#   ('bernard', 1),
#   ('bethesda', 1),
#   ('bin', 4),
#   ('binary', 2),
#   ('biochemistry', 1),
#   ('biomedical', 1),
#   ('bit', 1),
#   ('blackboard', 1),
#   ('blair', 1),
#   ('blood', 2),
#   ('blue', 1),
#   ('bmc', 1),
#   ('bold', 1),
#   ('borrow', 1),
#   ('boutique', 1),
#   ('box', 1),
#   ('boy', 2),
#   ('brain', 2),
#   ('brassiere', 1),
#   ('brazilian', 1),
#   ('brick', 1),
#   ('bridge', 2),
#   ('bright', 1),
#   ('bringer', 1),
#   ('brisei', 2),
#   ('britain', 3),
#   ('british', 9),
#   ('brother', 2),
#   ('buck', 1),
#   ('build', 2),
#   ('bureau', 2),
#   ('burial', 1),
#   ('burn', 1),
#   ('burney', 1),
#   ('bush', 1),
#   ('busy', 1),
#   ('buy', 1),
#   ('byrd', 1),
#   ('c', 6),
#   ('calculator', 1),
#   ('calendar', 1),
#   ('camel', 1),
#   ('camera', 2),
#   ('cancel', 1),
#   ('candidate', 5),
#   ('capita', 1),
#   ('capture', 2),
#   ('carbon', 3),
#   ('card', 1),
#   ('career', 1),
#   ('carter', 1),
#   ('cartoon', 1),
#   ('cash', 1),
#   ('cast', 1),
#   ('cat', 2),
#   ('catch', 1),
#   ('category', 1),
#   ('catholic', 1),
#   ('cattle', 1),
#   ('cautionary', 1),
#   ('cautious', 1),
#   ('ccns', 1),
#   ('cdd', 3),
#   ('census', 3),
#   ('centaur', 1),
#   ('center', 6),
#   ('centre', 3),
#   ('cet', 1),
#   ('cfm', 1),
#   ('challenge', 2),
#   ('challenger', 1),
#   ('chamber', 1),
#   ('chapter', 1),
#   ('charika', 1),
#   ('charin', 1),
#   ('charioteer', 1),
#   ...],
#  [('ability', 1),
#   ('able', 2),
#   ('abolish', 4),
#   ('abolition', 5),
#   ('about', 1),
#   ('accept', 3),
#   ('accord', 3),
#   ('account', 2),
#   ('achieve', 1),
#   ('act', 10),
#   ('action', 3),
#   ('active', 1),
#   ('activist', 1),
#   ('address', 7),
#   ('adopt', 3),
#   ('advance', 1),
#   ('african', 1),
#   ('afterwards', 3),
#   ('age', 4),
#   ('aggressive', 3),
#   ('agree', 3),
#   ('agricultural', 1),
#   ('aid', 4),
#   ('aim', 1),
#   ('alexander', 1),
#   ('alienate', 1),
#   ('allow', 14),
#   ('alone', 1),
#   ('already', 6),
#   ('also', 15),
#   ('altogether', 1),
#   ('always', 1),
#   ('ambiguous', 1),
#   ('american', 6),
#   ('amount', 1),
#   ('ancestor', 1),
#   ('ancient', 1),
#   ('andrew', 2),
#   ('anger', 1),
#   ('anti', 3),
#   ('apart', 1),
#   ('apparent', 1),
#   ('appeal', 2),
#   ('appear', 3),
#   ('approach', 2),
#   ('april', 5),
#   ('area', 4),
#   ('argue', 3),
#   ('army', 13),
#   ('arrive', 1),
#   ('article', 1),
#   ('as', 1),
#   ('assassination', 6),
#   ('assert', 1),
#   ('assist', 1),
#   ('attempt', 4),
#   ('attention', 1),
#   ('attribute', 1),
#   ('august', 3),
#   ('authority', 4),
#   ('avoid', 3),
#   ('away', 5),
#   ('back', 5),
#   ('bad', 1),
#   ('ballot', 1),
#   ('baltimore', 1),
#   ('band', 4),
#   ('bank', 4),
#   ('banking', 1),
#   ('base', 3),
#   ('be', 249),
#   ('become', 12),
#   ('begin', 5),
#   ('beginning', 1),
#   ('belief', 1),
#   ('believe', 9),
#   ('belong', 1),
#   ('better', 1),
#   ('bible', 1),
#   ('birth', 1),
#   ('black', 6),
#   ('blame', 1),
#   ('bob', 1),
#   ('body', 5),
#   ('book', 4),
#   ('border', 2),
#   ('bring', 4),
#   ('bullet', 1),
#   ('business', 1),
#   ('call', 6),
#   ('camp', 1),
#   ('can', 5),
#   ('capital', 5),
#   ('care', 1),
#   ('carry', 1),
#   ('case', 2),
#   ('cause', 4),
#   ('cease', 1),
#   ('central', 1),
#   ('century', 3),
#   ('certain', 1),
#   ('certainty', 1),
#   ('change', 3),
#   ('character', 1),
#   ('characterize', 1),
#   ('chief', 4),
#   ('child', 5),
#   ('choice', 4),
#   ('church', 4),
#   ('city', 5),
#   ('civil', 6),
#   ('claim', 7),
#   ('class', 2),
#   ('classical', 2),
#   ('clear', 2),
#   ('clearly', 2),
#   ('close', 3),
#   ('co', 3),
#   ('color', 1),
#   ('combat', 1),
#   ('come', 8),
#   ('comfort', 4),
#   ('common', 2),
#   ('community', 1),
#   ('company', 1),
#   ('compete', 3),
#   ('complete', 2),
#   ('concept', 1),
#   ('confederation', 1),
#   ('conflict', 1),
#   ('congress', 7),
#   ('conservative', 3),
#   ('consider', 4),
#   ('consistency', 1),
#   ('contemporary', 1),
#   ('context', 1),
#   ('continue', 3),
#   ('contribute', 1),
#   ('control', 8),
#   ('controversial', 1),
#   ('converse', 1),
#   ('cost', 2),
#   ('could', 14),
#   ('country', 3),
#   ('cover', 2),
#   ('create', 1),
#   ('creation', 2),
#   ('criticism', 2),
#   ('criticize', 5),
#   ('crowd', 1),
#   ('crush', 1),
#   ('current', 1),
#   ('d', 10),
#   ('damage', 1),
#   ('dan', 1),
#   ('date', 1),
#   ('david', 2),
#   ('day', 6),
#   ('deal', 1),
#   ('debate', 5),
#   ('december', 3),
#   ('decide', 4),
#   ('declare', 5),
#   ('dedicate', 1),
#   ('deep', 1),
#   ('defeat', 7),
#   ('defend', 4),
#   ('del', 1),
#   ('delay', 1),
#   ('democracy', 1),
#   ('democrat', 6),
#   ('democratic', 4),
#   ('desire', 5),
#   ('destroy', 6),
#   ('determine', 1),
#   ('develop', 2),
#   ('difference', 2),
#   ('difficulty', 3),
#   ('direct', 1),
#   ('discussion', 1),
#   ('dislike', 1),
#   ('distinct', 1),
#   ('divide', 3),
#   ('division', 1),
#   ('do', 32),
#   ('doctrine', 1),
#   ('drive', 1),
#   ('early', 9),
#   ('earth', 1),
#   ('eastern', 2),
#   ('easy', 1),
#   ('economic', 4),
#   ('economy', 1),
#   ('edition', 1),
#   ('education', 2),
#   ('effect', 1),
#   ('effort', 11),
#   ('either', 1),
#   ('elect', 10),
#   ('election', 15),
#   ('electoral', 8),
#   ('elite', 1),
#   ('emphasize', 1),
#   ('encounter', 1),
#   ('encourage', 3),
#   ('encyclopedia', 1),
#   ('end', 10),
#   ('enemy', 2),
#   ('engage', 3),
#   ('english', 3),
#   ('enough', 3),
#   ('ensure', 1),
#   ('enter', 3),
#   ('entirely', 2),
#   ('entry', 1),
#   ('equality', 3),
#   ('escape', 1),
#   ('especially', 2),
#   ('establish', 2),
#   ('europe', 1),
#   ('even', 6),
#   ('event', 1),
#   ('ever', 5),
#   ('everyone', 1),
#   ('evil', 1),
#   ('exist', 6),
#   ('expansion', 5),
#   ('expect', 5),
#   ('expense', 1),
#   ('experience', 2),
#   ('explicitly', 2),
#   ('expose', 1),
#   ('express', 3),
#   ('extend', 1),
#   ('extensive', 1),
#   ('external', 1),
#   ('face', 5),
#   ('fact', 1),
#   ('factory', 1),
#   ('fail', 4),
#   ('failure', 3),
#   ('fall', 1),
#   ('family', 6),
#   ('famous', 5),
#   ('far', 1),
#   ('favor', 5),
#   ('favorite', 1),
#   ('feature', 1),
#   ('february', 5),
#   ('feel', 2),
#   ('few', 6),
#   ('field', 1),
#   ('fight', 10),
#   ('figure', 1),
#   ('file', 1),
#   ('final', 1),
#   ('find', 4),
#   ('fine', 1),
#   ('first', 16),
#   ('folk', 1),
#   ('follow', 7),
#   ('following', 1),
#   ('food', 1),
#   ('force', 13),
#   ('foreign', 1),
#   ('form', 4),
#   ('formal', 1),
#   ('found', 1),
#   ('fourth', 1),
#   ('free', 20),
#   ('freely', 1),
#   ('friend', 1),
#   ('front', 1),
#   ('frustration', 1),
#   ('fundamental', 1),
#   ('further', 4),
#   ('g', 1),
#   ('gain', 1),
#   ('general', 17),
#   ('generally', 1),
#   ('generate', 1),
#   ('george', 2),
#   ('gesture', 1),
#   ('get', 1),
#   ('ghost', 1),
#   ('give', 12),
#   ('go', 6),
#   ('goal', 4),
#   ('god', 6),
#   ('good', 8),
#   ('government', 13),
#   ('great', 12),
#   ('greek', 7),
#   ('ground', 2),
#   ('group', 2),
#   ('grow', 5),
#   ('guide', 1),
#   ('hand', 1),
#   ('hard', 1),
#   ('harsh', 1),
#   ('have', 72),
#   ('head', 4),
#   ('hear', 2),
#   ('heavily', 1),
#   ('help', 6),
#   ('herbert', 1),
#   ('here', 3),
#   ('hide', 1),
#   ('high', 4),
#   ('highly', 1),
#   ('historian', 3),
#   ('history', 4),
#   ('hold', 9),
#   ('holder', 1),
#   ('home', 1),
#   ('hopkin', 2),
#   ('hour', 2),
#   ('how', 1),
#   ('however', 17),
#   ('hundred', 3),
#   ('ideology', 1),
#   ('image', 1),
#   ('imply', 1),
#   ('importance', 1),
#   ('important', 3),
#   ('impose', 3),
#   ('imprison', 1),
#   ('include', 4),
#   ('incorporate', 1),
#   ('increase', 1),
#   ('indian', 1),
#   ('individual', 1),
#   ('influence', 3),
#   ('influential', 1),
#   ('inspire', 2),
#   ('instead', 2),
#   ('institution', 3),
#   ('insurrection', 3),
#   ('intention', 1),
#   ('interest', 3),
#   ('interfere', 1),
#   ('interpret', 1),
#   ('involve', 3),
#   ('ireland', 1),
#   ('issue', 11),
#   ('january', 3),
#   ('joe', 1),
#   ('johns', 2),
#   ('join', 5),
#   ('joseph', 3),
#   ('just', 5),
#   ('justice', 1),
#   ('key', 3),
#   ('kill', 14),
#   ('king', 4),
#   ('kingdom', 1),
#   ('know', 7),
#   ('l', 1),
#   ('labor', 2),
#   ('lack', 3),
#   ('land', 9),
#   ('language', 1),
#   ('large', 1),
#   ('last', 5),
#   ('late', 2),
#   ('later', 9),
#   ('latin', 1),
#   ('law', 12),
#   ('lead', 7),
#   ('leader', 9),
#   ('leadership', 2),
#   ('learn', 2),
#   ('leave', 8),
#   ('less', 2),
#   ('let', 2),
#   ('liberation', 1),
#   ('liberty', 2),
#   ('life', 8),
#   ('limit', 1),
#   ('line', 4),
#   ('link', 1),
#   ('little', 2),
#   ('live', 3),
#   ('living', 1),
#   ('long', 4),
#   ('look', 2),
#   ('lose', 8),
#   ('low', 2),
#   ('main', 2),
#   ('maintain', 1),
#   ('major', 1),
#   ('majority', 1),
#   ('make', 13),
#   ('man', 15),
#   ('manual', 1),
#   ('many', 9),
#   ('mary', 5),
#   ('massacre', 1),
#   ('may', 9),
#   ('meaning', 1),
#   ('meet', 2),
#   ('meeting', 2),
#   ('member', 3),
#   ('message', 1),
#   ('mexico', 1),
#   ('mid', 2),
#   ('middle', 1),
#   ('militia', 1),
#   ('mind', 1),
#   ('modern', 1),
#   ('month', 3),
#   ('moral', 1),
#   ('more', 20),
#   ('most', 9),
#   ('move', 11),
#   ('much', 5),
#   ('multiple', 1),
#   ('music', 2),
#   ('musical', 1),
#   ('must', 3),
#   ('name', 6),
#   ('national', 11),
#   ('nature', 1),
#   ('nearly', 4),
#   ('need', 2),
#   ('never', 4),
#   ('nevertheless', 1),
#   ('new', 16),
#   ('north', 8),
#   ('not', 51),
#   ('note', 1),
#   ('notion', 1),
#   ('now', 5),
#   ('number', 1),
#   ('object', 2),
#   ('obvious', 1),
#   ('october', 1),
#   ('offer', 4),
#   ('official', 7),
#   ('often', 7),
#   ('old', 9),
#   ('one', 1),
#   ('only', 11),
#   ('opinion', 1),
#   ('opponent', 1),
#   ('opportunity', 1),
#   ('oppose', 7),
#   ('opposition', 5),
#   ('order', 3),
#   ('origin', 1),
#   ('other', 17),
#   ('own', 10),
#   ('owner', 1),
#   ('paper', 1),
#   ('parent', 4),
#   ('paris', 3),
#   ('part', 6),
#   ('particularly', 1),
#   ('party', 18),
#   ('pass', 4),
#   ('pay', 1),
#   ('peer', 1),
#   ('people', 3),
#   ('perhaps', 4),
#   ('period', 2),
#   ('person', 6),
#   ('personal', 3),
#   ('place', 2),
#   ('plain', 1),
#   ('platform', 2),
#   ('play', 9),
#   ('point', 4),
#   ('policy', 2),
#   ('politic', 5),
#   ('political', 8),
#   ('poor', 1),
#   ('popular', 2),
#   ('portray', 2),
#   ('position', 3),
#   ('possible', 2),
#   ('possibly', 1),
#   ('post', 1),
#   ('power', 10),
#   ('practice', 2),
#   ('predict', 1),
#   ('prediction', 1),
#   ('prepare', 1),
#   ('present', 3),
#   ('preserve', 4),
#   ('prevent', 1),
#   ('principle', 1),
#   ('prior', 1),
#   ('private', 1),
#   ('proclaim', 1),
#   ('prominent', 1),
#   ('proper', 1),
#   ('property', 3),
#   ('propose', 4),
#   ('prove', 1),
#   ('provide', 4),
#   ('publish', 2),
#   ('purpose', 2),
#   ('pursue', 1),
#   ('pursuit', 1),
#   ('race', 5),
#   ('racial', 1),
#   ('radical', 4),
#   ('range', 1),
#   ('rank', 1),
#   ('rather', 2),
#   ('re', 5),
#   ('react', 1),
#   ('read', 2),
#   ('reality', 1),
#   ('reason', 1),
#   ('rebellion', 6),
#   ('receive', 3),
#   ('recognize', 1),
#   ('record', 5),
#   ('red', 1),
#   ('refer', 2),
#   ('reference', 3),
#   ('reflect', 1),
#   ('refuse', 8),
#   ('regard', 1),
#   ('reject', 2),
#   ('rejection', 1),
#   ('relate', 2),
#   ('relation', 1),
#   ('relationship', 4),
#   ('relatively', 1),
#   ('religion', 1),
#   ('remain', 4),
#   ('repeatedly', 1),
#   ('represent', 2),
#   ('republican', 31),
#   ('resource', 1),
#   ('respond', 3),
#   ('rest', 1),
#   ('result', 1),
#   ('return', 3),
#   ('right', 5),
#   ('rise', 2),
#   ('rival', 3),
#   ('robert', 10),
#   ('rock', 2),
#   ('role', 5),
#   ('room', 1),
#   ('route', 1),
#   ('s', 12),
#   ('same', 3),
#   ('satisfaction', 1),
#   ('say', 18),
#   ('school', 2),
#   ('science', 1),
#   ('second', 10),
#   ('see', 14),
#   ('seek', 1),
#   ('seem', 4),
#   ('self', 1),
#   ('set', 6),
#   ('several', 5),
#   ('share', 4),
#   ('short', 1),
#   ('shortly', 2),
#   ('should', 1),
#   ('show', 7),
#   ('sight', 1),
#   ('sign', 9),
#   ('similar', 1),
#   ('simply', 1),
#   ('single', 3),
#   ('sir', 1),
#   ('sit', 2),
#   ('situation', 1),
#   ('skill', 1),
#   ('slight', 1),
#   ('small', 1),
#   ('so', 6),
#   ('social', 3),
#   ('society', 1),
#   ('something', 1),
#   ('sometimes', 2),
#   ('song', 6),
#   ('soon', 5),
#   ('sound', 1),
#   ('source', 3),
#   ('sovereignty', 1),
#   ('speak', 3),
#   ('specifically', 1),
#   ('speech', 8),
#   ('spencer', 1),
#   ('spend', 5),
#   ('split', 1),
#   ('spread', 1),
#   ('stage', 2),
#   ('stanley', 1),
#   ('start', 1),
#   ('state', 61),
#   ('stay', 1),
#   ('stephen', 2),
#   ('still', 5),
#   ('story', 7),
#   ('strategy', 4),
#   ('strike', 1),
#   ('strong', 5),
#   ('strongly', 2),
#   ('struggle', 1),
#   ('style', 1),
#   ('subject', 1),
#   ('success', 2),
#   ('successful', 3),
#   ('such', 11),
#   ('suggest', 1),
#   ('support', 14),
#   ('supporter', 2),
#   ('sympathizer', 2),
#   ('system', 4),
#   ('t', 1),
#   ('take', 17),
#   ('talk', 2),
#   ('teach', 1),
#   ('teacher', 1),
#   ('team', 1),
#   ('tell', 3),
#   ('temporary', 1),
#   ('tend', 1),
#   ('term', 10),
#   ('text', 1),
#   ('then', 7),
#   ('theory', 2),
#   ('there', 11),
#   ('therefore', 1),
#   ('thereof', 2),
#   ('thing', 1),
#   ('think', 3),
#   ('third', 2),
#   ('thus', 6),
#   ('time', 24),
#   ('today', 2),
#   ('todd', 7),
#   ('together', 1),
#   ('too', 3),
#   ('total', 2),
#   ('trade', 1),
#   ('transform', 1),
#   ('troop', 5),
#   ('true', 2),
#   ('try', 2),
#   ('turn', 5),
#   ('uk', 1),
#   ('ultimately', 1),
#   ('unable', 1),
#   ('uncommon', 1),
#   ('union', 47),
#   ('unite', 3),
#   ('united', 16),
#   ('unity', 1),
#   ('universal', 1),
#   ('unknown', 1),
#   ('unusually', 1),
#   ('uprising', 1),
#   ('use', 6),
#   ('usually', 2),
#   ('value', 1),
#   ('very', 2),
#   ('victory', 9),
#   ('view', 8),
#   ('vision', 3),
#   ('voice', 2),
#   ('vote', 12),
#   ('wait', 3),
#   ('war', 59),
#   ('way', 5),
#   ('weaken', 2),
#   ('wealth', 1),
#   ('well', 4),
#   ('western', 3),
#   ('when', 15),
#   ('where', 5),
#   ('whereby', 1),
#   ('white', 1),
#   ('will', 10),
#   ('william', 7),
#   ('wing', 1),
#   ('wish', 2),
#   ('woman', 3),
#   ('word', 3),
#   ('work', 7),
#   ('world', 4),
#   ('would', 37),
#   ('write', 4),
#   ('writing', 1),
#   ('year', 12),
#   ('abandon', 1),
#   ('academy', 1),
#   ('accompany', 1),
#   ('achaean', 1),
#   ('achille', 67),
#   ('achilleus', 1),
#   ('acquire', 1),
#   ('actually', 1),
#   ('add', 1),
#   ('administration', 5),
#   ('ajax', 3),
#   ('alabama', 1),
#   ('album', 4),
#   ('america', 4),
# ...
#   ('calm', 1),
#   ('can', 3),
#   ('capable', 1),
#   ('carry', 5),
#   ('case', 1),
#   ('cause', 2),
#   ('central', 1),
#   ('century', 2),
#   ('certain', 3),
#   ('chance', 1),
#   ('change', 7),
#   ('character', 6),
#   ('characteristic', 3),
#   ('chat', 1),
#   ('chief', 2),
#   ('child', 8),
#   ('christian', 1),
#   ('church', 6),
#   ('city', 2),
#   ('civil', 1),
#   ('civilization', 1),
#   ('claim', 3),
#   ('class', 4),
#   ('classic', 3),
#   ('classical', 1),
#   ('clear', 1),
#   ('close', 4),
#   ('coalition', 2),
#   ('collective', 1),
#   ('come', 8),
#   ('common', 3),
#   ('commonly', 1),
#   ('communal', 1),
#   ('communication', 1),
#   ('communist', 1),
#   ('company', 2),
#   ('complete', 3),
#   ('complex', 2),
#   ('concern', 3),
#   ('conclusion', 2),
#   ('condition', 3),
#   ('confederation', 3),
#   ('confine', 1),
#   ('conflict', 2),
#   ('congress', 7),
#   ('conquest', 2),
#   ('conscience', 1),
#   ('consider', 1),
#   ('consolidate', 1),
#   ('contact', 1),
#   ('contemporary', 3),
#   ('continue', 4),
#   ('control', 1),
#   ('conversation', 1),
#   ('cost', 1),
#   ('could', 13),
#   ('council', 3),
#   ('country', 3),
#   ('create', 5),
#   ('crisis', 1),
#   ('critical', 1),
#   ('criticism', 1),
#   ('crush', 3),
#   ('cry', 2),
#   ('culminate', 3),
#   ('current', 5),
#   ('d', 3),
#   ('dangerous', 2),
#   ('date', 4),
#   ('day', 2),
#   ('deal', 3),
#   ('december', 8),
#   ('decide', 1),
#   ('declare', 6),
#   ('defeat', 3),
#   ('define', 1),
#   ('delay', 1),
#   ('denmark', 1),
#   ('denounce', 1),
#   ('describe', 2),
#   ('desire', 1),
#   ('determine', 2),
#   ('develop', 2),
#   ('development', 3),
#   ('difference', 1),
#   ('different', 1),
#   ('difficult', 2),
#   ('difficulty', 1),
#   ('direct', 1),
#   ('direction', 2),
#   ('disorder', 1),
#   ('display', 2),
#   ('divide', 1),
#   ('do', 7),
#   ('don', 1),
#   ('drive', 2),
#   ('due', 1),
#   ('e', 3),
#   ('early', 7),
#   ('economic', 1),
#   ('economical', 1),
#   ('edit', 5),
#   ('edition', 5),
#   ('education', 3),
#   ('educational', 1),
#   ('effect', 3),
#   ('effort', 3),
#   ('elaborate', 4),
#   ('elect', 2),
#   ('element', 1),
#   ('else', 1),
#   ('emotional', 1),
#   ('encourage', 1),
#   ('end', 8),
#   ('enemy', 3),
#   ('engage', 2),
#   ('english', 4),
#   ('enjoyment', 1),
#   ('enough', 2),
#   ('enter', 3),
#   ('entry', 1),
#   ('environment', 1),
#   ('era', 1),
#   ('escape', 1),
#   ('establish', 1),
#   ('europe', 22),
#   ('european', 6),
#   ('even', 7),
#   ('event', 3),
#   ('ever', 1),
#   ('everyone', 1),
#   ('exile', 2),
#   ('exist', 1),
#   ('existence', 2),
#   ('expansion', 1),
#   ('expense', 1),
#   ('experiment', 1),
#   ('express', 2),
#   ('external', 3),
#   ('eye', 3),
#   ('fact', 6),
#   ('fall', 3),
#   ('family', 1),
#   ('famous', 3),
#   ('far', 4),
#   ('favor', 2),
#   ('favorite', 1),
#   ('feature', 1),
#   ('feel', 5),
#   ('few', 2),
#   ('fight', 1),
#   ('figure', 3),
#   ('find', 8),
#   ('first', 21),
#   ('fluctuation', 1),
#   ('follow', 7),
#   ('force', 9),
#   ('foreign', 3),
#   ('form', 8),
#   ('formation', 2),
#   ('formulate', 1),
#   ('forum', 1),
#   ('forward', 1),
#   ('fourth', 2),
#   ('france', 5),
#   ('franco', 2),
#   ('frederick', 3),
#   ('free', 5),
#   ('freedom', 4),
#   ('freely', 1),
#   ('french', 12),
#   ('friend', 4),
#   ('front', 1),
#   ('full', 1),
#   ('fund', 2),
#   ('further', 2),
#   ('g', 1),
#   ('general', 6),
#   ('generally', 2),
#   ('george', 3),
#   ('germany', 5),
#   ('get', 3),
#   ('gift', 1),
#   ('give', 12),
#   ('go', 5),
#   ('goal', 1),
#   ('godwin', 1),
#   ('good', 3),
#   ('government', 9),
#   ('great', 19),
#   ('greek', 14),
#   ('group', 1),
#   ('hand', 5),
#   ('harmony', 1),
#   ('have', 72),
#   ('head', 4),
#   ('hear', 1),
#   ('heavily', 1),
#   ('help', 2),
#   ('here', 1),
#   ('high', 1),
#   ('historian', 1),
#   ('history', 8),
#   ('hold', 2),
#   ('holy', 6),
#   ('home', 2),
#   ('how', 1),
#   ('however', 14),
#   ('human', 1),
#   ('hypocrisy', 1),
#   ('ideology', 1),
#   ('ii', 11),
#   ('ill', 4),
#   ('illegitimate', 1),
#   ('imaginative', 1),
#   ('important', 5),
#   ('impose', 1),
#   ('impossible', 1),
#   ('improve', 1),
#   ('inclined', 1),
#   ('include', 1),
#   ('incorporate', 1),
#   ('increase', 2),
#   ('indeed', 4),
#   ('influence', 7),
#   ('information', 1),
#   ('initiate', 1),
#   ('insight', 1),
#   ('inspire', 2),
#   ('instead', 1),
#   ('institute', 1),
#   ('institution', 3),
#   ('intellectual', 1),
#   ('intention', 4),
#   ('interest', 10),
#   ('interfere', 1),
#   ('internal', 2),
#   ('international', 1),
#   ('internet', 1),
#   ('interpret', 1),
#   ('intervention', 4),
#   ('introduce', 2),
#   ('involve', 1),
#   ('ireland', 1),
#   ('issue', 11),
#   ('italian', 1),
#   ('italy', 3),
#   ('item', 1),
#   ('iv', 3),
#   ('january', 6),
#   ('jason', 1),
#   ('join', 3),
#   ('just', 1),
#   ('justice', 1),
#   ('justify', 1),
#   ('kill', 2),
#   ('kind', 1),
#   ('king', 21),
#   ('kingdom', 5),
#   ('know', 7),
#   ('knowledge', 1),
#   ('lack', 1),
#   ('land', 2),
#   ('language', 6),
#   ('large', 7),
#   ('last', 5),
#   ('later', 10),
#   ('latin', 1),
#   ('law', 6),
#   ('lead', 6),
#   ('leader', 3),
#   ('learn', 1),
#   ('leave', 6),
#   ('left', 1),
#   ('less', 5),
#   ('let', 1),
#   ('liberal', 8),
#   ('liberalism', 2),
#   ('liberation', 1),
#   ('liberty', 5),
#   ('life', 16),
#   ('limit', 4),
#   ('line', 1),
#   ('link', 4),
#   ('list', 1),
#   ('little', 11),
#   ('live', 3),
#   ('long', 2),
#   ('look', 1),
#   ('m', 2),
#   ('main', 3),
#   ('mainly', 1),
#   ('maintain', 3),
#   ('major', 1),
#   ('make', 19),
#   ('man', 9),
#   ('manifesto', 1),
#   ('manner', 1),
#   ('many', 7),
#   ('mary', 1),
#   ('match', 1),
#   ('may', 10),
#   ('mean', 3),
#   ('meaning', 2),
#   ('mediate', 1),
#   ('mediation', 1),
#   ('medium', 1),
#   ('meet', 3),
#   ('meeting', 3),
#   ('mikhail', 3),
#   ('mind', 6),
#   ('miss', 1),
#   ('model', 1),
#   ('modern', 3),
#   ('moment', 4),
#   ('month', 2),
#   ('moral', 1),
#   ('more', 17),
#   ('most', 11),
#   ('move', 2),
#   ('movement', 2),
#   ('much', 4),
#   ('must', 1),
#   ('name', 6),
#   ('national', 2),
#   ('natural', 3),
#   ('nature', 4),
#   ('necessary', 2),
#   ('negotiation', 3),
#   ('network', 1),
#   ('never', 8),
#   ('new', 16),
#   ('next', 3),
#   ('north', 1),
#   ('not', 26),
#   ('notable', 2),
#   ('note', 2),
#   ('now', 5),
#   ('number', 1),
#   ('object', 2),
#   ('objection', 1),
#   ('occupation', 2),
#   ('october', 4),
#   ('offer', 3),
#   ('official', 6),
#   ('often', 2),
#   ('old', 2),
#   ('once', 5),
#   ('one', 4),
#   ('only', 12),
#   ('open', 4),
#   ('opinion', 1),
#   ('opportunity', 2),
#   ('oppose', 1),
#   ('opposition', 2),
#   ('oppression', 1),
#   ('order', 9),
#   ('organization', 1),
#   ('organize', 1),
#   ('origin', 1),
#   ('other', 19),
#   ('overthrow', 1),
#   ('own', 13),
#   ('page', 1),
#   ('parent', 1),
#   ('paris', 3),
#   ('part', 9),
#   ('particular', 1),
#   ('party', 3),
#   ('pass', 3),
#   ('past', 1),
#   ('pay', 1),
#   ('peasant', 3),
#   ('people', 11),
#   ('perhaps', 2),
#   ('period', 3),
#   ('person', 1),
#   ('personal', 8),
#   ('peter', 2),
#   ('place', 7),
#   ('play', 3),
#   ('point', 3),
#   ('policy', 10),
#   ('politic', 3),
#   ('political', 7),
#   ('poor', 1),
#   ('popular', 1),
#   ('population', 1),
#   ('position', 3),
#   ('positive', 1),
#   ('possession', 1),
#   ('possible', 2),
#   ('power', 14),
#   ('precursor', 1),
#   ('predecessor', 1),
#   ('prepare', 1),
#   ('present', 2),
#   ('prevent', 2),
#   ('price', 3),
#   ('priest', 1),
#   ('principle', 11),
#   ('prison', 1),
#   ('private', 7),
#   ('privilege', 2),
#   ('problem', 3),
#   ('proceed', 2),
#   ('proclaim', 3),
#   ('profit', 1),
#   ('prominent', 1),
#   ('proper', 1),
#   ('propose', 2),
#   ('proprietor', 5),
#   ('prove', 3),
#   ('provide', 1),
#   ('publicly', 1),
#   ('publish', 2),
#   ('purpose', 5),
#   ('quite', 1),
#   ('radical', 2),
#   ('rather', 1),
#   ('re', 1),
#   ('reaction', 1),
#   ('read', 3),
#   ('reason', 1),
#   ('receive', 3),
#   ('recognize', 1),
#   ('reduce', 2),
#   ('refer', 1),
#   ('reference', 6),
#   ('refuse', 3),
#   ('regard', 4),
#   ('regime', 1),
#   ('region', 1),
#   ('regulate', 1),
#   ('relation', 7),
#   ('religion', 1),
#   ('religious', 2),
#   ('remain', 3),
#   ('report', 1),
#   ('represent', 1),
#   ('repressive', 1),
#   ('repudiate', 1),
#   ('resist', 2),
#   ('resistance', 1),
#   ('resort', 1),
#   ('resource', 3),
#   ('respect', 3),
#   ('respective', 1),
#   ('responsibility', 1),
#   ('restrict', 1),
#   ('result', 4),
#   ('retain', 2),
#   ('return', 6),
#   ('revolution', 3),
#   ('revolutionary', 6),
#   ('revolutionist', 1),
#   ('right', 5),
#   ('role', 1),
#   ('rome', 2),
#   ('rousseau', 1),
#   ('rule', 7),
#   ('ruler', 7),
#   ('rumor', 1),
#   ('rural', 2),
#   ('russia', 30),
#   ('russian', 30),
#   ('s', 7),
#   ('same', 5),
#   ('say', 10),
#   ('second', 4),
#   ('secular', 1),
#   ('see', 8),
#   ('seek', 2),
#   ('seem', 3),
#   ('seize', 4),
#   ('self', 1),
#   ('sense', 1),
#   ('serious', 1),
#   ('several', 1),
#   ('short', 1),
#   ('should', 10),
#   ('show', 2),
#   ('sign', 3),
#   ('significant', 1),
#   ('similar', 1),
#   ('sir', 1),
#   ('small', 2),
#   ('so', 5),
#   ('social', 3),
#   ('society', 3),
#   ('soon', 3),
#   ('source', 1),
#   ('soviet', 1),
#   ('speak', 2),
#   ('spirit', 5),
#   ('stage', 1),
#   ('start', 3),
#   ('state', 11),
#   ('stay', 1),
#   ('stephen', 1),
#   ('still', 13),
#   ('strike', 2),
#   ('strongly', 1),
#   ('subject', 5),
#   ('succeed', 4),
#   ('success', 1),
#   ('successful', 2),
#   ('successor', 1),
#   ('such', 6),
#   ('suggest', 1),
#   ('support', 5),
#   ('suppress', 2),
#   ('suppression', 2),
#   ('suspect', 1),
#   ('swiss', 1),
#   ('symbol', 1),
#   ('symptom', 1),
#   ('system', 5),
#   ('t', 1),
#   ('take', 15),
#   ('taxation', 1),
#   ('teach', 1),
#   ('technique', 2),
#   ('technology', 1),
#   ('tend', 1),
#   ('tendency', 1),
#   ('term', 2),
#   ('test', 1),
#   ('text', 4),
#   ('then', 6),
#   ('theoretical', 3),
#   ('theory', 1),
#   ('there', 4),
#   ('therefore', 3),
#   ('thing', 2),
#   ('think', 2),
#   ('thinking', 1),
#   ('third', 3),
#   ('thought', 2),
#   ('thus', 2),
#   ('time', 21),
#   ('today', 2),
#   ('together', 6),
#   ('too', 5),
#   ('topic', 2),
#   ('trade', 1),
#   ('tradition', 1),
#   ('traditional', 3),
#   ('train', 1),
#   ('transform', 1),
#   ('troop', 1),
#   ('true', 5),
#   ('try', 4),
#   ('turn', 3),
#   ('typically', 1),
#   ('ukraine', 1),
#   ('unable', 1),
#   ('union', 1),
#   ('united', 2),
#   ('universal', 3),
#   ('uphold', 1),
#   ('uprising', 1),
#   ('use', 5),
#   ('utopian', 1),
#   ('vain', 2),
#   ('various', 2),
#   ('very', 1),
#   ('victor', 1),
#   ('victory', 3),
#   ('view', 5),
#   ('vision', 1),
#   ('wait', 1),
#   ('want', 7),
#   ('war', 14),
#   ('way', 7),
#   ('wealth', 1),
#   ('well', 7),
#   ('western', 1),
#   ('when', 13),
#   ('where', 4),
#   ('will', 2),
#   ('william', 4),
#   ('wish', 2),
#   ('withdrawal', 1),
#   ('word', 1),
#   ('work', 3),
#   ('worker', 2),
#   ('working', 1),
#   ('world', 13),
#   ('would', 17),
#   ('write', 7),
#   ('writing', 1),
#   ('year', 16),
#   ('abandon', 1),
#   ('actually', 1),
#   ('add', 4),
#   ('administration', 3),
#   ('air', 1),
#   ('anchor', 1),
#   ('announcement', 1),
#   ('asia', 1),
#   ('assistance', 1),
#   ('atmosphere', 2),
#   ('attack', 2),
#   ('attract', 1),
#   ('austria', 2),
#   ('available', 1),
#   ('average', 1),
#   ('basis', 1),
#   ('battle', 6),
#   ('bc', 16),
#   ('bear', 4),
#   ('beloved', 1),
#   ('britain', 1),
#   ('british', 1),
#   ('brother', 8),
#   ('build', 2),
#   ('burial', 1),
#   ('buy', 3),
#   ('catch', 1),
#   ('catholic', 1),
#   ('cautious', 1),
#   ('centre', 1),
#   ('choose', 2),
#   ('christ', 1),
#   ('closer', 1),
#   ('code', 2),
#   ('commerce', 1),
#   ('completely', 2),
#   ('compose', 1),
#   ('concert', 1),
#   ('conduct', 3),
#   ('confusion', 1),
#   ('constitution', 2),
#   ('consult', 2),
#   ('content', 1),
#   ('correspond', 1),
#   ('court', 5),
#   ('criminal', 1),
#   ('cross', 3),
#   ('dare', 1),
#   ('death', 23),
#   ('deny', 1),
#   ('depend', 1),
#   ('discover', 1),
#   ('document', 2),
#   ('east', 2),
#   ('educate', 3),
#   ('edward', 2),
#   ('everything', 1),
#   ('evidence', 1),
#   ('exhaust', 2),
#   ('father', 12),
#   ('financial', 2),
#   ('fire', 1),
#   ('fit', 2),
#   ('forget', 1),
#   ('former', 6),
#   ('frequently', 1),
#   ('fresh', 1),
#   ('fulfil', 1),
#   ('function', 1),
#   ('german', 2),
#   ('giovanni', 1),
#   ('glory', 1),
#   ('grant', 2),
#   ('growth', 1),
#   ('handsome', 1),
#   ('heart', 1),
#   ('heavy', 2),
#   ('hecuba', 1),
#   ('hint', 1),
#   ('homer', 1),
#   ('house', 1),
#   ('html', 1),
#   ('http', 2),
#   ('ideal', 5),
#   ('increasingly', 3),
#   ('independent', 2),
#   ('india', 1),
#   ('indication', 1),
#   ('industry', 1),
#   ('inscription', 1),
#   ('instance', 1),
#   ('intend', 1),
#   ('interrupt', 1),
#   ('introduction', 1),
#   ('iron', 1),
#   ('ivan', 1),
#   ('july', 2),
#   ('june', 4),
#   ('largely', 2),
#   ('latter', 1),
#   ('league', 4),
#   ('letter', 2),
#   ('light', 1),
#   ('literature', 1),
#   ('local', 1),
#   ('london', 5),
#   ('longer', 2),
#   ('loss', 2),
#   ('love', 5),
#   ('march', 9),
#   ('marry', 8),
#   ('master', 3),
#   ('matter', 2),
#   ('meanwhile', 2),
#   ('measure', 5),
#   ('memory', 1),
#   ('mention', 1),
#   ('merely', 2),
#   ('military', 8),
#   ('minister', 9),
#   ('minority', 1),
#   ('mistake', 1),
#   ('mortal', 1),
#   ('mother', 1),
#   ('mount', 1),
#   ('nation', 7),
#   ('native', 3),
#   ('neutral', 1),
#   ('news', 1),
#   ('no', 2),
#   ('none', 3),
#   ('numerous', 1),
#   ('o', 1),
#   ('obtain', 3),
#   ('office', 3),
#   ('oracle', 1),
#   ('overwhelm', 1),
#   ('palace', 1),
#   ('partly', 3),
#   ('perform', 2),
#   ('persian', 1),
#   ('personality', 1),
#   ('plot', 1),
#   ('potential', 1),
#   ('presence', 1),
#   ('previously', 1),
#   ('prime', 1),
#   ('print', 3),
#   ('produce', 4),
#   ('project', 2),
#   ('protest', 5),
#   ('protestant', 1),
#   ('public', 5),
#   ('push', 1),
#   ('question', 5),
#   ('raise', 2),
#   ('rapidly', 1),
#   ('readily', 1),
#   ('refuge', 1),
#   ('release', 1),
#   ('require', 1),
#   ('revenue', 1),
#   ('risk', 1),
#   ('river', 2),
#   ('road', 1),
#   ('roman', 5),
#   ('run', 1),
#   ('save', 1),
#   ('secure', 2),
#   ('select', 1),
#   ('send', 6),
#   ('september', 2),
#   ('seriously', 1),
#   ('serve', 2),
#   ('settle', 1),
#   ('settlement', 1),
#   ('severe', 1),
#   ('ship', 1),
#   ('siberia', 2),
#   ('side', 3),
#   ('slavery', 1),
#   ('soldier', 2),
#   ('son', 17),
#   ('south', 1),
#   ('southern', 1),
#   ('stand', 1),
#   ('statement', 1),
#   ('station', 1),
#   ('successfully', 2),
#   ('sudden', 1),
#   ('suffer', 3),
#   ('sultan', 1),
#   ('summer', 1),
#   ('supervision', 1),
#   ('sympathize', 1),
#   ('task', 1),
#   ('territory', 2),
#   ('thea', 1),
#   ('thereafter', 1),
#   ('thessaly', 1),
#   ('thousand', 2),
#   ('town', 2),
#   ('traffic', 1),
#   ('trait', 1),
#   ('treat', 2),
#   ('treaty', 7),
#   ('truce', 2),
#   ('trust', 3),
#   ('truth', 3),
#   ('type', 3),
#   ('uncertain', 1),
#   ('understanding', 2),
#   ('university', 1),
#   ('visit', 2),
#   ('west', 1),
#   ('while', 1),
#   ('whole', 1),
#   ('win', 1),
#   ('winter', 1),
#   ('withdraw', 2),
#   ('wound', 2),
#   ('www', 2),
#   ('young', 7),
#   ('youth', 2),
#   ('accuse', 1),
#   ('actor', 2),
#   ('affair', 7),
#   ('affirm', 1),
#   ('again', 1),
#   ('agreement', 1),
#   ('alarm', 1),
#   ('alexandra', 4),
#   ('ally', 2),
#   ('anything', 1),
#   ('appoint', 2),
#   ('approve', 2),
#   ('assassinate', 5),
#   ('assembly', 1),
#   ('assure', 1),
#   ('authorize', 1),
#   ('b', 1),
#   ('beard', 1),
#   ('bless', 1),
#   ('break', 2),
#   ('bull', 1),
#   ('byzantine', 1),
#   ('cabinet', 1),
#   ('campaign', 6),
#   ('charge', 2),
#   ('charity', 1),
#   ('citizen', 1),
#   ('colleague', 1),
#   ('colony', 1),
#   ('combine', 3),
#   ('complicated', 1),
#   ('conquer', 1),
#   ('considerable', 1),
#   ('constitutional', 1),
#   ('contract', 2),
#   ('convention', 2),
#   ('course', 1),
#   ('cousin', 1),
#   ('credit', 2),
#   ('crime', 1),
#   ('dante', 2),
#   ('danube', 3),
#   ('daughter', 12),
#   ('declaration', 1),
#   ('decline', 1),
#   ('defense', 1),
#   ('determined', 1),
#   ('die', 12),
#   ('diplomatic', 1),
#   ('divine', 2),
#   ('dixon', 1),
#   ('domestic', 3),
#   ('draw', 5),
#   ('dream', 3),
#   ('earlier', 1),
#   ('egypt', 1),
#   ('eld', 1),
#   ('emancipation', 6),
#   ('engagement', 2),
#   ('england', 2),
#   ('epirus', 6),
#   ('epitome', 1),
#   ('execute', 3),
#   ('exercise', 1),
#   ('expand', 1),
#   ('fate', 2),
#   ('fellow', 1),
#   ('finally', 1),
#   ('flee', 1),
#   ('friendship', 3),
#   ('frontier', 3),
#   ('future', 3),
#   ('garrison', 1),
#   ('generous', 1),
#   ('governor', 3),
#   ('grandson', 1),
#   ('grapple', 1),
#   ('greatly', 1),
#   ('guard', 3),
#   ('happy', 1),
#   ('henry', 1),
#   ('hire', 1),
#   ('hope', 4),
#   ('iii', 5),
#   ('illumination', 1),
#   ('importantly', 1),
#   ('improvement', 1),
#   ('inactivity', 1),
#   ('intimate', 1),
#   ('invasion', 1),
#   ('john', 1),
#   ('judgment', 2),
#   ('judicial', 1),
#   ('jump', 1),
#   ('kidnap', 2),
#   ('legal', 1),
#   ('legislation', 1),
#   ('lord', 2),
#   ('loyal', 2),
#   ...]]

# %%
# Step 4: Train the LDA model
lda_model = LdaMulticore(corpus=corpus,
                         id2word=dct,
                         random_state=100,
                         num_topics=7,
                         passes=10,
                         chunksize=1000,
                         batch=False,
                         alpha='asymmetric',
                         decay=0.5,
                         offset=64,
                         eta=None,
                         eval_every=0,
                         iterations=100,
                         gamma_threshold=0.001,
                         per_word_topics=True)

# save the model
lda_model.save('lda_model.model')

# See the topics
lda_model.print_topics(-1)
# Out:
# 2019-03-24 15:39:23,735 : INFO : using asymmetric alpha [0.26219156, 0.19027454, 0.14931786, 0.12287004, 0.104381524, 0.090729296, 0.080235206]
# 2019-03-24 15:39:23,736 : INFO : using symmetric eta at 0.14285714285714285
# 2019-03-24 15:39:23,746 : INFO : using serial LDA version on this node
# 2019-03-24 15:39:23,785 : INFO : running online LDA training, 7 topics, 10 passes over the supplied corpus of 100 documents, updating every 7000 documents, evaluating every ~0 documents, iterating 100x with a convergence threshold of 0.001000
# 2019-03-24 15:39:23,796 : INFO : training LDA model using 7 processes
# 2019-03-24 15:39:23,853 : INFO : PROGRESS: pass 0, dispatched chunk #0 = documents up to #100/100, outstanding queue size 1
# 2019-03-24 15:39:24,824 : INFO : topic #6 (0.080): 0.002*"be" + 0.001*"have" + 0.000*"agave" + 0.000*"american" + 0.000*"not" + 0.000*"also" + 0.000*"year" + 0.000*"use" + 0.000*"state" + 0.000*"s"
# 2019-03-24 15:39:24,826 : INFO : topic #5 (0.091): 0.015*"be" + 0.004*"have" + 0.002*"other" + 0.001*"not" + 0.001*"also" + 0.001*"use" + 0.001*"s" + 0.001*"american" + 0.001*"time" + 0.001*"first"
# 2019-03-24 15:39:24,828 : INFO : topic #2 (0.149): 0.005*"be" + 0.002*"have" + 0.001*"also" + 0.001*"not" + 0.000*"state" + 0.000*"use" + 0.000*"many" + 0.000*"first" + 0.000*"can" + 0.000*"most"
# 2019-03-24 15:39:24,830 : INFO : topic #1 (0.190): 0.004*"be" + 0.001*"have" + 0.000*"american" + 0.000*"s" + 0.000*"use" + 0.000*"other" + 0.000*"year" + 0.000*"not" + 0.000*"also" + 0.000*"first"
# 2019-03-24 15:39:24,832 : INFO : topic #0 (0.262): 0.010*"be" + 0.003*"have" + 0.001*"not" + 0.001*"state" + 0.001*"use" + 0.001*"other" + 0.001*"first" + 0.001*"s" + 0.001*"also" + 0.001*"most"
# 2019-03-24 15:39:24,833 : INFO : topic diff=0.253302, rho=0.125000
# 2019-03-24 15:39:24,835 : INFO : PROGRESS: pass 1, dispatched chunk #0 = documents up to #100/100, outstanding queue size 1
# 2019-03-24 15:39:25,710 : INFO : topic #6 (0.080): 0.002*"be" + 0.001*"have" + 0.000*"agave" + 0.000*"american" + 0.000*"not" + 0.000*"also" + 0.000*"year" + 0.000*"use" + 0.000*"state" + 0.000*"s"
# 2019-03-24 15:39:25,712 : INFO : topic #5 (0.091): 0.015*"be" + 0.004*"have" + 0.002*"other" + 0.001*"also" + 0.001*"not" + 0.001*"use" + 0.001*"s" + 0.001*"american" + 0.001*"time" + 0.001*"first"
# 2019-03-24 15:39:25,713 : INFO : topic #2 (0.149): 0.005*"be" + 0.002*"have" + 0.001*"also" + 0.001*"not" + 0.000*"state" + 0.000*"use" + 0.000*"many" + 0.000*"first" + 0.000*"can" + 0.000*"most"
# 2019-03-24 15:39:25,715 : INFO : topic #1 (0.190): 0.004*"be" + 0.001*"have" + 0.000*"american" + 0.000*"s" + 0.000*"use" + 0.000*"other" + 0.000*"year" + 0.000*"not" + 0.000*"also" + 0.000*"first"
# 2019-03-24 15:39:25,717 : INFO : topic #0 (0.262): 0.010*"be" + 0.003*"have" + 0.001*"not" + 0.001*"state" + 0.001*"use" + 0.001*"other" + 0.001*"first" + 0.001*"s" + 0.001*"also" + 0.001*"most"
# 2019-03-24 15:39:25,718 : INFO : topic diff=0.132249, rho=0.123939
# 2019-03-24 15:39:25,720 : INFO : PROGRESS: pass 2, dispatched chunk #0 = documents up to #100/100, outstanding queue size 1
# 2019-03-24 15:39:26,244 : INFO : topic #6 (0.080): 0.002*"be" + 0.001*"have" + 0.000*"agave" + 0.000*"american" + 0.000*"not" + 0.000*"also" + 0.000*"year" + 0.000*"use" + 0.000*"state" + 0.000*"s"
# 2019-03-24 15:39:26,247 : INFO : topic #5 (0.091): 0.015*"be" + 0.004*"have" + 0.002*"other" + 0.001*"also" + 0.001*"not" + 0.001*"use" + 0.001*"s" + 0.001*"american" + 0.001*"time" + 0.001*"first"
# 2019-03-24 15:39:26,248 : INFO : topic #2 (0.149): 0.005*"be" + 0.002*"have" + 0.001*"also" + 0.000*"not" + 0.000*"state" + 0.000*"use" + 0.000*"many" + 0.000*"first" + 0.000*"can" + 0.000*"most"
# 2019-03-24 15:39:26,250 : INFO : topic #1 (0.190): 0.004*"be" + 0.001*"have" + 0.000*"american" + 0.000*"s" + 0.000*"use" + 0.000*"other" + 0.000*"year" + 0.000*"not" + 0.000*"also" + 0.000*"first"
# 2019-03-24 15:39:26,252 : INFO : topic #0 (0.262): 0.010*"be" + 0.003*"have" + 0.001*"not" + 0.001*"state" + 0.001*"use" + 0.001*"other" + 0.001*"first" + 0.001*"s" + 0.001*"also" + 0.001*"most"
# 2019-03-24 15:39:26,253 : INFO : topic diff=0.099497, rho=0.122998
# 2019-03-24 15:39:26,255 : INFO : PROGRESS: pass 3, dispatched chunk #0 = documents up to #100/100, outstanding queue size 1
# 2019-03-24 15:39:26,764 : INFO : topic #6 (0.080): 0.002*"be" + 0.001*"have" + 0.000*"agave" + 0.000*"american" + 0.000*"not" + 0.000*"also" + 0.000*"year" + 0.000*"use" + 0.000*"state" + 0.000*"s"
# 2019-03-24 15:39:26,765 : INFO : topic #5 (0.091): 0.015*"be" + 0.004*"have" + 0.002*"other" + 0.001*"also" + 0.001*"not" + 0.001*"use" + 0.001*"s" + 0.001*"american" + 0.001*"time" + 0.001*"first"
# 2019-03-24 15:39:26,767 : INFO : topic #2 (0.149): 0.004*"be" + 0.002*"have" + 0.001*"also" + 0.000*"not" + 0.000*"state" + 0.000*"use" + 0.000*"many" + 0.000*"first" + 0.000*"can" + 0.000*"most"
# 2019-03-24 15:39:26,769 : INFO : topic #1 (0.190): 0.004*"be" + 0.001*"have" + 0.000*"american" + 0.000*"s" + 0.000*"use" + 0.000*"other" + 0.000*"year" + 0.000*"not" + 0.000*"also" + 0.000*"first"
# 2019-03-24 15:39:26,771 : INFO : topic #0 (0.262): 0.010*"be" + 0.003*"have" + 0.001*"not" + 0.001*"state" + 0.001*"use" + 0.001*"other" + 0.001*"first" + 0.001*"s" + 0.001*"also" + 0.001*"most"
# 2019-03-24 15:39:26,772 : INFO : topic diff=0.093501, rho=0.122078
# 2019-03-24 15:39:26,774 : INFO : PROGRESS: pass 4, dispatched chunk #0 = documents up to #100/100, outstanding queue size 1
# 2019-03-24 15:39:27,317 : INFO : topic #6 (0.080): 0.002*"be" + 0.001*"have" + 0.000*"agave" + 0.000*"american" + 0.000*"not" + 0.000*"also" + 0.000*"year" + 0.000*"use" + 0.000*"state" + 0.000*"s"
# 2019-03-24 15:39:27,319 : INFO : topic #5 (0.091): 0.015*"be" + 0.004*"have" + 0.001*"other" + 0.001*"also" + 0.001*"not" + 0.001*"use" + 0.001*"s" + 0.001*"american" + 0.001*"time" + 0.001*"first"
# 2019-03-24 15:39:27,321 : INFO : topic #2 (0.149): 0.004*"be" + 0.002*"have" + 0.000*"also" + 0.000*"not" + 0.000*"state" + 0.000*"use" + 0.000*"many" + 0.000*"first" + 0.000*"can" + 0.000*"most"
# 2019-03-24 15:39:27,323 : INFO : topic #1 (0.190): 0.004*"be" + 0.001*"have" + 0.000*"american" + 0.000*"s" + 0.000*"use" + 0.000*"other" + 0.000*"year" + 0.000*"not" + 0.000*"also" + 0.000*"first"
# 2019-03-24 15:39:27,324 : INFO : topic #0 (0.262): 0.010*"be" + 0.003*"have" + 0.001*"not" + 0.001*"state" + 0.001*"use" + 0.001*"other" + 0.001*"first" + 0.001*"s" + 0.001*"also" + 0.001*"most"
# 2019-03-24 15:39:27,326 : INFO : topic diff=0.094288, rho=0.121179
# 2019-03-24 15:39:27,328 : INFO : PROGRESS: pass 5, dispatched chunk #0 = documents up to #100/100, outstanding queue size 1
# 2019-03-24 15:39:27,847 : INFO : topic #6 (0.080): 0.002*"be" + 0.001*"have" + 0.000*"agave" + 0.000*"american" + 0.000*"not" + 0.000*"also" + 0.000*"year" + 0.000*"use" + 0.000*"state" + 0.000*"s"
# 2019-03-24 15:39:27,849 : INFO : topic #5 (0.091): 0.014*"be" + 0.004*"have" + 0.001*"other" + 0.001*"also" + 0.001*"not" + 0.001*"use" + 0.001*"s" + 0.001*"american" + 0.001*"time" + 0.001*"first"
# 2019-03-24 15:39:27,851 : INFO : topic #2 (0.149): 0.004*"be" + 0.002*"have" + 0.000*"also" + 0.000*"not" + 0.000*"state" + 0.000*"use" + 0.000*"many" + 0.000*"first" + 0.000*"can" + 0.000*"most"
# 2019-03-24 15:39:27,853 : INFO : topic #1 (0.190): 0.004*"be" + 0.001*"have" + 0.000*"american" + 0.000*"s" + 0.000*"use" + 0.000*"other" + 0.000*"year" + 0.000*"not" + 0.000*"also" + 0.000*"first"
# 2019-03-24 15:39:27,855 : INFO : topic #0 (0.262): 0.009*"be" + 0.002*"have" + 0.001*"not" + 0.001*"state" + 0.001*"use" + 0.001*"other" + 0.001*"first" + 0.001*"s" + 0.001*"also" + 0.001*"most"
# 2019-03-24 15:39:27,856 : INFO : topic diff=0.097847, rho=0.120299
# 2019-03-24 15:39:27,858 : INFO : PROGRESS: pass 6, dispatched chunk #0 = documents up to #100/100, outstanding queue size 1
# 2019-03-24 15:39:28,374 : INFO : topic #6 (0.080): 0.001*"be" + 0.001*"have" + 0.000*"agave" + 0.000*"american" + 0.000*"not" + 0.000*"also" + 0.000*"year" + 0.000*"use" + 0.000*"state" + 0.000*"s"
# 2019-03-24 15:39:28,376 : INFO : topic #5 (0.091): 0.014*"be" + 0.003*"have" + 0.001*"other" + 0.001*"also" + 0.001*"not" + 0.001*"use" + 0.001*"s" + 0.001*"american" + 0.001*"time" + 0.001*"first"
# 2019-03-24 15:39:28,378 : INFO : topic #2 (0.149): 0.004*"be" + 0.002*"have" + 0.000*"also" + 0.000*"not" + 0.000*"state" + 0.000*"use" + 0.000*"many" + 0.000*"first" + 0.000*"can" + 0.000*"most"
# 2019-03-24 15:39:28,380 : INFO : topic #1 (0.190): 0.003*"be" + 0.001*"have" + 0.000*"american" + 0.000*"s" + 0.000*"use" + 0.000*"other" + 0.000*"year" + 0.000*"not" + 0.000*"also" + 0.000*"first"
# 2019-03-24 15:39:28,381 : INFO : topic #0 (0.262): 0.009*"be" + 0.002*"have" + 0.001*"not" + 0.001*"state" + 0.001*"use" + 0.001*"other" + 0.001*"first" + 0.001*"s" + 0.001*"also" + 0.001*"most"
# 2019-03-24 15:39:28,383 : INFO : topic diff=0.102739, rho=0.119438
# 2019-03-24 15:39:28,384 : INFO : PROGRESS: pass 7, dispatched chunk #0 = documents up to #100/100, outstanding queue size 1
# 2019-03-24 15:39:28,872 : INFO : topic #6 (0.080): 0.001*"be" + 0.001*"have" + 0.000*"agave" + 0.000*"american" + 0.000*"not" + 0.000*"also" + 0.000*"year" + 0.000*"use" + 0.000*"state" + 0.000*"s"
# 2019-03-24 15:39:28,874 : INFO : topic #5 (0.091): 0.014*"be" + 0.003*"have" + 0.001*"other" + 0.001*"also" + 0.001*"not" + 0.001*"use" + 0.001*"s" + 0.001*"american" + 0.001*"time" + 0.001*"first"
# 2019-03-24 15:39:28,876 : INFO : topic #2 (0.149): 0.004*"be" + 0.001*"have" + 0.000*"also" + 0.000*"not" + 0.000*"state" + 0.000*"use" + 0.000*"many" + 0.000*"first" + 0.000*"can" + 0.000*"most"
# 2019-03-24 15:39:28,879 : INFO : topic #1 (0.190): 0.003*"be" + 0.001*"have" + 0.000*"american" + 0.000*"s" + 0.000*"use" + 0.000*"other" + 0.000*"year" + 0.000*"not" + 0.000*"also" + 0.000*"first"
# 2019-03-24 15:39:28,881 : INFO : topic #0 (0.262): 0.009*"be" + 0.002*"have" + 0.001*"not" + 0.001*"state" + 0.001*"use" + 0.001*"other" + 0.001*"first" + 0.001*"s" + 0.001*"also" + 0.001*"most"
# 2019-03-24 15:39:28,882 : INFO : topic diff=0.108263, rho=0.118595
# 2019-03-24 15:39:28,884 : INFO : PROGRESS: pass 8, dispatched chunk #0 = documents up to #100/100, outstanding queue size 1
# 2019-03-24 15:39:29,321 : INFO : topic #6 (0.080): 0.001*"be" + 0.001*"have" + 0.000*"agave" + 0.000*"american" + 0.000*"not" + 0.000*"also" + 0.000*"year" + 0.000*"use" + 0.000*"state" + 0.000*"s"
# 2019-03-24 15:39:29,323 : INFO : topic #5 (0.091): 0.013*"be" + 0.003*"have" + 0.001*"other" + 0.001*"also" + 0.001*"not" + 0.001*"use" + 0.001*"s" + 0.001*"american" + 0.001*"time" + 0.001*"first"
# 2019-03-24 15:39:29,325 : INFO : topic #2 (0.149): 0.004*"be" + 0.001*"have" + 0.000*"also" + 0.000*"not" + 0.000*"state" + 0.000*"use" + 0.000*"many" + 0.000*"first" + 0.000*"can" + 0.000*"most"
# 2019-03-24 15:39:29,326 : INFO : topic #1 (0.190): 0.003*"be" + 0.001*"have" + 0.000*"american" + 0.000*"s" + 0.000*"use" + 0.000*"other" + 0.000*"year" + 0.000*"not" + 0.000*"also" + 0.000*"first"
# 2019-03-24 15:39:29,328 : INFO : topic #0 (0.262): 0.009*"be" + 0.002*"have" + 0.001*"not" + 0.001*"state" + 0.001*"use" + 0.001*"other" + 0.001*"first" + 0.001*"s" + 0.001*"also" + 0.001*"most"
# 2019-03-24 15:39:29,329 : INFO : topic diff=0.113989, rho=0.117769
# 2019-03-24 15:39:29,331 : INFO : PROGRESS: pass 9, dispatched chunk #0 = documents up to #100/100, outstanding queue size 1
# 2019-03-24 15:39:29,832 : INFO : topic #6 (0.080): 0.001*"be" + 0.000*"have" + 0.000*"agave" + 0.000*"american" + 0.000*"not" + 0.000*"also" + 0.000*"year" + 0.000*"use" + 0.000*"state" + 0.000*"s"
# 2019-03-24 15:39:29,834 : INFO : topic #5 (0.091): 0.013*"be" + 0.003*"have" + 0.001*"other" + 0.001*"also" + 0.001*"not" + 0.001*"use" + 0.001*"s" + 0.001*"american" + 0.001*"time" + 0.001*"first"
# 2019-03-24 15:39:29,835 : INFO : topic #2 (0.149): 0.004*"be" + 0.001*"have" + 0.000*"also" + 0.000*"not" + 0.000*"state" + 0.000*"use" + 0.000*"many" + 0.000*"first" + 0.000*"can" + 0.000*"most"
# 2019-03-24 15:39:29,837 : INFO : topic #1 (0.190): 0.003*"be" + 0.001*"have" + 0.000*"american" + 0.000*"s" + 0.000*"use" + 0.000*"other" + 0.000*"year" + 0.000*"not" + 0.000*"also" + 0.000*"first"
# 2019-03-24 15:39:29,839 : INFO : topic #0 (0.262): 0.008*"be" + 0.002*"have" + 0.001*"not" + 0.001*"state" + 0.001*"use" + 0.001*"other" + 0.001*"first" + 0.001*"s" + 0.001*"also" + 0.001*"most"
# 2019-03-24 15:39:29,840 : INFO : topic diff=0.119616, rho=0.116961
# 2019-03-24 15:39:29,953 : INFO : saving LdaState object under lda_model.model.state, separately None
# 2019-03-24 15:39:29,969 : INFO : saved lda_model.model.state
# 2019-03-24 15:39:30,003 : INFO : saving LdaMulticore object under lda_model.model, separately ['expElogbeta', 'sstats']
# 2019-03-24 15:39:30,005 : INFO : storing np array 'expElogbeta' to lda_model.model.expElogbeta.npy
# 2019-03-24 15:39:30,010 : INFO : not storing attribute id2word
# 2019-03-24 15:39:30,011 : INFO : not storing attribute state
# 2019-03-24 15:39:30,012 : INFO : not storing attribute dispatcher
# 2019-03-24 15:39:30,015 : INFO : saved lda_model.model
# 2019-03-24 15:39:30,017 : INFO : topic #0 (0.262): 0.008*"be" + 0.002*"have" + 0.001*"not" + 0.001*"state" + 0.001*"use" + 0.001*"other" + 0.001*"first" + 0.001*"s" + 0.001*"also" + 0.001*"most"
# 2019-03-24 15:39:30,019 : INFO : topic #1 (0.190): 0.003*"be" + 0.001*"have" + 0.000*"american" + 0.000*"s" + 0.000*"use" + 0.000*"other" + 0.000*"year" + 0.000*"not" + 0.000*"also" + 0.000*"first"
# 2019-03-24 15:39:30,021 : INFO : topic #2 (0.149): 0.004*"be" + 0.001*"have" + 0.000*"also" + 0.000*"not" + 0.000*"state" + 0.000*"use" + 0.000*"many" + 0.000*"first" + 0.000*"can" + 0.000*"most"
# 2019-03-24 15:39:30,023 : INFO : topic #3 (0.123): 0.005*"be" + 0.001*"have" + 0.001*"also" + 0.001*"not" + 0.001*"use" + 0.000*"s" + 0.000*"american" + 0.000*"first" + 0.000*"many" + 0.000*"see"
# 2019-03-24 15:39:30,025 : INFO : topic #4 (0.104): 0.051*"be" + 0.011*"have" + 0.005*"not" + 0.004*"also" + 0.004*"use" + 0.004*"other" + 0.004*"s" + 0.003*"state" + 0.003*"american" + 0.003*"first"
# 2019-03-24 15:39:30,027 : INFO : topic #5 (0.091): 0.013*"be" + 0.003*"have" + 0.001*"other" + 0.001*"also" + 0.001*"not" + 0.001*"use" + 0.001*"s" + 0.001*"american" + 0.001*"time" + 0.001*"first"
# 2019-03-24 15:39:30,029 : INFO : topic #6 (0.080): 0.001*"be" + 0.000*"have" + 0.000*"agave" + 0.000*"american" + 0.000*"not" + 0.000*"also" + 0.000*"year" + 0.000*"use" + 0.000*"state" + 0.000*"s"
# [(0,
#   '0.008*"be" + 0.002*"have" + 0.001*"not" + 0.001*"state" + 0.001*"use" + 0.001*"other" + 0.001*"first" + 0.001*"s" + 0.001*"also" + 0.001*"most"'),
#  (1,
#   '0.003*"be" + 0.001*"have" + 0.000*"american" + 0.000*"s" + 0.000*"use" + 0.000*"other" + 0.000*"year" + 0.000*"not" + 0.000*"also" + 0.000*"first"'),
#  (2,
#   '0.004*"be" + 0.001*"have" + 0.000*"also" + 0.000*"not" + 0.000*"state" + 0.000*"use" + 0.000*"many" + 0.000*"first" + 0.000*"can" + 0.000*"most"'),
#  (3,
#   '0.005*"be" + 0.001*"have" + 0.001*"also" + 0.001*"not" + 0.001*"use" + 0.000*"s" + 0.000*"american" + 0.000*"first" + 0.000*"many" + 0.000*"see"'),
#  (4,
#   '0.051*"be" + 0.011*"have" + 0.005*"not" + 0.004*"also" + 0.004*"use" + 0.004*"other" + 0.004*"s" + 0.003*"state" + 0.003*"american" + 0.003*"first"'),
#  (5,
#   '0.013*"be" + 0.003*"have" + 0.001*"other" + 0.001*"also" + 0.001*"not" + 0.001*"use" + 0.001*"s" + 0.001*"american" + 0.001*"time" + 0.001*"first"'),
#  (6,
#   '0.001*"be" + 0.000*"have" + 0.000*"agave" + 0.000*"american" + 0.000*"not" + 0.000*"also" + 0.000*"year" + 0.000*"use" + 0.000*"state" + 0.000*"s"')]

# %% [markdown]
# The lda_model.print_topics shows what words contributed to which of the 7 topics, along with the weightage of the word’s contribution to that topic.
#
# You can see the words like ‘also’, ‘many’ coming across different topics. So I would add such words to the stop_words list to remove them and further tune to topic model for optimal number of topics.
#
# LdaMulticore() supports parallel processing. Alternately you could also try and see what topics the LdaModel() gives.

# %% [markdown]
# ### 12. How to interpret the LDA Topic Model’s output?
# The lda_model object supports indexing. That is, if you pass a document (list of words) to the lda_model, it provides 3 things:
#
# The topic(s) that document belongs to along with percentage.
# The topic(s) each word in that document belongs to.
# The topic(s) each word in that document belongs to AND the phi values.
# So, what is phi value?
#
# Phi value is the probability of the word belonging to that particular topic. And the sum of phi values for a given word adds up to the number of times that word occurred in that document.
#
# For example, in below output for the 0th document, the word with id=0 belongs to topic number 6 and the phi value is 3.999. That means, the word with id=0 appeared 4 times in the 0th document.

# %%
for c in lda_model[corpus[5:8]]:
    print("Document Topics      : ", c[0])      # [(Topics, Perc Contrib)]
    print("Word id, Topics      : ", c[1][:3])  # [(Word id, [Topics])]
    print("Phi Values (word id) : ", c[2][:2])  # [(Word id, [(Topic, Phi Value)])]
    print("Word, Topics         : ", [(dct[wd], topic) for wd, topic in c[1][:2]])   # [(Word, [Topics])]
    print("Phi Values (word)    : ", [(dct[wd], topic) for wd, topic in c[2][:2]])  # [(Word, [(Topic, Phi Value)])]
    print("------------------------------------------------------\n")
# Out:
# Document Topics      :  [(4, 0.99983835)]
# Word id, Topics      :  [(1, [4]), (6, [4]), (10, [4])]
# Phi Values (word id) :  [(1, [(4, 2.9978013)]), (6, [(4, 1.9995625)])]
# Word, Topics         :  [('ability', [4]), ('about', [4])]
# Phi Values (word)    :  [('ability', [(4, 2.9978013)]), ('about', [(4, 1.9995625)])]
# ------------------------------------------------------
#
# Document Topics      :  [(4, 0.99984616)]
# Word id, Topics      :  [(1, [4]), (6, [4]), (13, [4])]
# Phi Values (word id) :  [(1, [(4, 5.995603)]), (6, [(4, 1.999563)])]
# Word, Topics         :  [('ability', [4]), ('about', [4])]
# Phi Values (word)    :  [('ability', [(4, 5.995603)]), ('about', [(4, 1.999563)])]
# ------------------------------------------------------
#
# Document Topics      :  [(4, 0.9998578)]
# Word id, Topics      :  [(2, [4]), (6, [4]), (13, [4])]
# Phi Values (word id) :  [(2, [(4, 0.99949414)]), (6, [(4, 0.9997814)])]
# Word, Topics         :  [('able', [4]), ('about', [4])]
# Phi Values (word)    :  [('able', [(4, 0.99949414)]), ('about', [(4, 0.9997814)])]
# ------------------------------------------------------

# %% [markdown]
# ### 13. How to create a LSI topic model using gensim?
# The syntax for using an LSI model is similar to how we built the LDA model, except that we will use the LsiModel().

# %%
# other info on LSI with gensim: https://www.datacamp.com/community/tutorials/discovering-hidden-topics-python
# https://nlpforhackers.io/topic-modeling/

# %%
from gensim.models import LsiModel

# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=dct, num_topics=7, decay=0.5)

# View Topics
pprint(lsi_model.print_topics(-1))
#> [(0, '0.262*"also" + 0.197*"state" + 0.197*"american" + 0.178*"first" + '
#>   '0.151*"many" + 0.149*"time" + 0.147*"year" + 0.130*"person" + 0.130*"world" '
#>   '+ 0.124*"war"'),
#>  (1, '0.937*"agave" + 0.164*"asia" + 0.100*"aruba" + 0.063*"plant" + 0.053*"var" '
#>   '+ 0.052*"state" + 0.045*"east" + 0.044*"congress" + -0.042*"first" + '
#>   '0.041*"maguey"'),
#>  (2, '0.507*"american" + 0.180*"football" + 0.179*"player" + 0.168*"war" + '
#>   '0.150*"british" + -0.140*"also" + 0.114*"ball" + 0.110*"day" + '
#>   '-0.107*"atheism" + -0.106*"god"'),
#>  (3, '-0.362*"apollo" + 0.248*"lincoln" + 0.211*"state" + -0.172*"player" + '
#>   '-0.151*"football" + 0.127*"union" + -0.125*"ball" + 0.124*"government" + '
#>   '-0.116*"moon" + 0.116*"jews"'),
#>  (4, '-0.363*"atheism" + -0.334*"god" + -0.329*"lincoln" + -0.230*"apollo" + '
#>   '-0.215*"atheist" + -0.143*"abraham" + 0.136*"island" + -0.132*"aristotle" + '
#>   '0.124*"aluminium" + -0.119*"belief"'),
#>  (5, '-0.360*"apollo" + 0.344*"atheism" + -0.326*"lincoln" + 0.226*"god" + '
#>   '0.205*"atheist" + 0.139*"american" + -0.130*"lunar" + 0.128*"football" + '
#>   '-0.125*"moon" + 0.114*"belief"'),
#>  (6, '-0.313*"lincoln" + 0.226*"apollo" + -0.166*"football" + -0.163*"war" + '
#>   '0.162*"god" + 0.153*"australia" + -0.148*"play" + -0.146*"ball" + '
#>   '0.122*"atheism" + -0.122*"line"')]
# Out:
# 2019-03-24 15:54:28,363 : INFO : using serial LSI version on this node
# 2019-03-24 15:54:28,365 : INFO : updating model with new documents
# 2019-03-24 15:54:28,365 : INFO : preparing a new chunk of documents
# 2019-03-24 15:54:28,444 : INFO : using 100 extra samples and 2 power iterations
# 2019-03-24 15:54:28,449 : INFO : 1st phase: constructing (43849, 107) action matrix
# 2019-03-24 15:54:28,470 : INFO : orthonormalizing (43849, 107) action matrix
# 2019-03-24 15:54:29,541 : INFO : 2nd phase: running dense svd on (107, 100) matrix
# 2019-03-24 15:54:29,567 : INFO : computing the final decomposition
# 2019-03-24 15:54:29,568 : INFO : keeping 7 factors (discarding 22.019% of energy spectrum)
# 2019-03-24 15:54:29,584 : INFO : processed documents up to #100
# 2019-03-24 15:54:29,586 : INFO : topic #0(3425.455): 0.905*"be" + 0.194*"have" + 0.083*"not" + 0.077*"use" + 0.076*"also" + 0.067*"other" + 0.061*"s" + 0.053*"state" + 0.050*"first" + 0.046*"most"
# 2019-03-24 15:54:29,588 : INFO : topic #1(577.507): 0.934*"agave" + 0.166*"asia" + 0.099*"aruba" + 0.082*"state" + 0.065*"plant" + 0.050*"east" + 0.050*"century" + 0.049*"island" + 0.046*"congress" + 0.045*"var"
# 2019-03-24 15:54:29,590 : INFO : topic #2(463.668): -0.484*"american" + -0.202*"war" + -0.162*"state" + -0.155*"player" + -0.147*"football" + -0.145*"b" + -0.143*"british" + 0.130*"be" + -0.122*"day" + -0.112*"australia"
# 2019-03-24 15:54:29,592 : INFO : topic #3(368.742): 0.226*"state" + 0.211*"lincoln" + -0.178*"player" + -0.174*"football" + -0.163*"line" + -0.151*"american" + -0.148*"play" + 0.147*"have" + -0.141*"ball" + 0.118*"atheism"
# 2019-03-24 15:54:29,594 : INFO : topic #4(350.497): -0.342*"apollo" + -0.276*"lincoln" + 0.161*"american" + -0.151*"would" + -0.135*"god" + 0.134*"island" + -0.133*"atheism" + -0.121*"not" + -0.120*"alexander" + -0.111*"man"
# 2019-03-24 15:54:29,596 : INFO : topic #0(3425.455): 0.905*"be" + 0.194*"have" + 0.083*"not" + 0.077*"use" + 0.076*"also" + 0.067*"other" + 0.061*"s" + 0.053*"state" + 0.050*"first" + 0.046*"most"
# 2019-03-24 15:54:29,598 : INFO : topic #1(577.507): 0.934*"agave" + 0.166*"asia" + 0.099*"aruba" + 0.082*"state" + 0.065*"plant" + 0.050*"east" + 0.050*"century" + 0.049*"island" + 0.046*"congress" + 0.045*"var"
# 2019-03-24 15:54:29,600 : INFO : topic #2(463.668): -0.484*"american" + -0.202*"war" + -0.162*"state" + -0.155*"player" + -0.147*"football" + -0.145*"b" + -0.143*"british" + 0.130*"be" + -0.122*"day" + -0.112*"australia"
# 2019-03-24 15:54:29,602 : INFO : topic #3(368.742): 0.226*"state" + 0.211*"lincoln" + -0.178*"player" + -0.174*"football" + -0.163*"line" + -0.151*"american" + -0.148*"play" + 0.147*"have" + -0.141*"ball" + 0.118*"atheism"
# 2019-03-24 15:54:29,604 : INFO : topic #4(350.497): -0.342*"apollo" + -0.276*"lincoln" + 0.161*"american" + -0.151*"would" + -0.135*"god" + 0.134*"island" + -0.133*"atheism" + -0.121*"not" + -0.120*"alexander" + -0.111*"man"
# 2019-03-24 15:54:29,607 : INFO : topic #5(341.450): -0.334*"apollo" + 0.178*"football" + 0.172*"atheism" + 0.167*"play" + 0.167*"line" + 0.143*"ball" + 0.137*"player" + 0.127*"anarchist" + 0.116*"such" + 0.113*"can"
# 2019-03-24 15:54:29,609 : INFO : topic #6(333.516): 0.347*"atheism" + 0.304*"god" + 0.239*"american" + 0.207*"atheist" + 0.176*"b" + -0.140*"have" + 0.124*"belief" + 0.115*"not" + -0.114*"africa" + 0.095*"religion"
# [(0,
#   '0.905*"be" + 0.194*"have" + 0.083*"not" + 0.077*"use" + 0.076*"also" + '
#   '0.067*"other" + 0.061*"s" + 0.053*"state" + 0.050*"first" + 0.046*"most"'),
#  (1,
#   '0.934*"agave" + 0.166*"asia" + 0.099*"aruba" + 0.082*"state" + '
#   '0.065*"plant" + 0.050*"east" + 0.050*"century" + 0.049*"island" + '
#   '0.046*"congress" + 0.045*"var"'),
#  (2,
#   '-0.484*"american" + -0.202*"war" + -0.162*"state" + -0.155*"player" + '
#   '-0.147*"football" + -0.145*"b" + -0.143*"british" + 0.130*"be" + '
#   '-0.122*"day" + -0.112*"australia"'),
#  (3,
#   '0.226*"state" + 0.211*"lincoln" + -0.178*"player" + -0.174*"football" + '
#   '-0.163*"line" + -0.151*"american" + -0.148*"play" + 0.147*"have" + '
#   '-0.141*"ball" + 0.118*"atheism"'),
#  (4,
#   '-0.342*"apollo" + -0.276*"lincoln" + 0.161*"american" + -0.151*"would" + '
#   '-0.135*"god" + 0.134*"island" + -0.133*"atheism" + -0.121*"not" + '
#   '-0.120*"alexander" + -0.111*"man"'),
#  (5,
#   '-0.334*"apollo" + 0.178*"football" + 0.172*"atheism" + 0.167*"play" + '
#   '0.167*"line" + 0.143*"ball" + 0.137*"player" + 0.127*"anarchist" + '
#   '0.116*"such" + 0.113*"can"'),
#  (6,
#   '0.347*"atheism" + 0.304*"god" + 0.239*"american" + 0.207*"atheist" + '
#   '0.176*"b" + -0.140*"have" + 0.124*"belief" + 0.115*"not" + -0.114*"africa" '
#   '+ 0.095*"religion"')]
